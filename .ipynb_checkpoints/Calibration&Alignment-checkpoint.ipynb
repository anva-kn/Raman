# %% [markdown]
# # SERS and Raman data calibration and alignment

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tools.ramanflow.read_data import ReadData as rd
from tools.ramanflow.prep_data import PrepData as rpd

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %% [markdown]
# ## Read the data

# %% [markdown]
# ### Indene and Raman

# %% [markdown]
# #### Wavenumber support

# %%
f_sup_785_650 = np.array([25.4348,26.1163,26.7976,27.4788,28.1599,28.8409,29.5218,30.2026,30.8832,31.5637,32.2442,32.9244,33.6046,34.2847,34.9646,35.6444,36.3242,37.0037,37.6832,38.3626,39.0418,39.7209,40.4000,41.0788,41.7576,42.4363,43.1148,43.7932,44.4715,45.1497,45.8278,46.5058,47.1836,47.8613,48.5389,49.2164,49.8938,50.5711,51.2482,51.9252,52.6021,53.2789,53.9556,54.6322,55.3086,55.9849,56.6611,57.3372,58.0132,58.6891,59.3648,60.0404,60.7159,61.3913,62.0666,62.7418,63.4168,64.0917,64.7665,65.4412,66.1158,66.7903,67.4646,68.1389,68.8130,69.4870,70.1608,70.8346,71.5083,72.1818,72.8552,73.5285,74.2017,74.8747,75.5477,76.2205,76.8933,77.5659,78.2383,78.9107,79.5830,80.2551,80.9271,81.5990,82.2708,82.9425,83.6140,84.2855,84.9568,85.6280,86.2991,86.9701,87.6409,88.3117,88.9823,89.6528,90.3232,90.9935,91.6637,92.3337,93.0037,93.6735,94.3432,95.0128,95.6822,96.3516,97.0208,97.6899,98.3589,99.0278,99.6966,100.3653,101.0338,101.7022,102.3705,103.0387,103.7068,104.3748,105.0426,105.7104,106.3780,107.0455,107.7129,108.3801,109.0473,109.7143,110.3812,111.0480,111.7147,112.3813,113.0478,113.7141,114.3803,115.0464,115.7124,116.3783,117.0441,117.7097,118.3753,119.0407,119.7060,120.3712,121.0363,121.7012,122.3661,123.0308,123.6954,124.3599,125.0243,125.6885,126.3527,127.0167,127.6806,128.3445,129.0081,129.6717,130.3352,130.9985,131.6617,132.3248,132.9878,133.6507,134.3135,134.9761,135.6387,136.3011,136.9634,137.6256,138.2877,138.9496,139.6115,140.2732,140.9348,141.5963,142.2577,142.9189,143.5801,144.2411,144.9021,145.5629,146.2236,146.8841,147.5446,148.2049,148.8652,149.5253,150.1853,150.8452,151.5050,152.1646,152.8242,153.4836,154.1429,154.8021,155.4612,156.1201,156.7790,157.4377,158.0963,158.7549,159.4133,160.0715,160.7297,161.3877,162.0457,162.7035,163.3612,164.0188,164.6763,165.3336,165.9909,166.6480,167.3050,167.9619,168.6187,169.2754,169.9319,170.5884,171.2447,171.9009,172.5570,173.2130,173.8689,174.5246,175.1802,175.8358,176.4912,177.1465,177.8017,178.4567,179.1117,179.7665,180.4212,181.0758,181.7303,182.3847,183.0390,183.6931,184.3472,185.0011,185.6549,186.3086,186.9622,187.6156,188.2690,188.9222,189.5753,190.2283,190.8812,191.5340,192.1867,192.8392,193.4917,194.1440,194.7962,195.4483,196.1003,196.7521,197.4039,198.0555,198.7070,199.3584,200.0097,200.6609,201.3120,201.9629,202.6137,203.2645,203.9151,204.5656,205.2159,205.8662,206.5164,207.1664,207.8163,208.4661,209.1158,209.7654,210.4149,211.0642,211.7134,212.3626,213.0116,213.6605,214.3093,214.9579,215.6065,216.2549,216.9032,217.5515,218.1996,218.8475,219.4954,220.1432,220.7908,221.4383,222.0858,222.7331,223.3802,224.0273,224.6743,225.3211,225.9679,226.6145,227.2610,227.9074,228.5536,229.1998,229.8459,230.4918,231.1376,231.7833,232.4289,233.0744,233.7198,234.3650,235.0102,235.6552,236.3001,236.9449,237.5896,238.2342,238.8786,239.5230,240.1672,240.8113,241.4553,242.0992,242.7430,243.3867,244.0302,244.6737,245.3170,245.9602,246.6033,247.2463,247.8891,248.5319,249.1745,249.8171,250.4595,251.1018,251.7440,252.3861,253.0280,253.6699,254.3116,254.9532,255.5947,256.2361,256.8774,257.5186,258.1596,258.8006,259.4414,260.0822,260.7227,261.3632,262.0036,262.6439,263.2840,263.9241,264.5640,265.2038,265.8435,266.4831,267.1226,267.7619,268.4012,269.0403,269.6793,270.3182,270.9570,271.5957,272.2343,272.8727,273.5111,274.1493,274.7874,275.4254,276.0633,276.7011,277.3387,277.9763,278.6137,279.2511,279.8883,280.5254,281.1624,281.7993,282.4360,283.0727,283.7092,284.3456,284.9819,285.6181,286.2542,286.8902,287.5260,288.1618,288.7974,289.4330,290.0684,290.7036,291.3388,291.9739,292.6089,293.2437,293.8784,294.5131,295.1476,295.7820,296.4162,297.0504,297.6845,298.3184,298.9522,299.5860,300.2196,300.8531,301.4865,302.1197,302.7529,303.3859,304.0189,304.6517,305.2844,305.9170,306.5494,307.1818,307.8141,308.4462,309.0782,309.7102,310.3420,310.9737,311.6053,312.2367,312.8681,313.4993,314.1305,314.7615,315.3924,316.0232,316.6539,317.2845,317.9149,318.5453,319.1755,319.8056,320.4356,321.0655,321.6953,322.3250,322.9545,323.5840,324.2133,324.8426,325.4717,326.1007,326.7296,327.3583,327.9870,328.6156,329.2440,329.8723,330.5005,331.1287,331.7567,332.3845,333.0123,333.6400,334.2675,334.8949,335.5222,336.1495,336.7766,337.4035,338.0304,338.6572,339.2838,339.9104,340.5368,341.1631,341.7893,342.4154,343.0414,343.6672,344.2930,344.9186,345.5442,346.1696,346.7949,347.4201,348.0452,348.6702,349.2950,349.9198,350.5444,351.1689,351.7933,352.4177,353.0418,353.6659,354.2899,354.9138,355.5375,356.1611,356.7846,357.4081,358.0313,358.6545,359.2776,359.9006,360.5234,361.1462,361.7688,362.3913,363.0137,363.6360,364.2582,364.8803,365.5022,366.1241,366.7458,367.3675,367.9890,368.6104,369.2317,369.8528,370.4739,371.0949,371.7157,372.3365,372.9571,373.5776,374.1980,374.8183,375.4385,376.0585,376.6785,377.2983,377.9181,378.5377,379.1572,379.7766,380.3959,381.0151,381.6341,382.2531,382.8719,383.4907,384.1093,384.7278,385.3462,385.9645,386.5827,387.2007,387.8187,388.4366,389.0543,389.6719,390.2894,390.9068,391.5241,392.1413,392.7584,393.3753,393.9922,394.6089,395.2255,395.8420,396.4584,397.0747,397.6909,398.3070,398.9229,399.5388,400.1545,400.7701,401.3857,402.0011,402.6164,403.2315,403.8466,404.4616,405.0764,405.6912,406.3058,406.9203,407.5347,408.1490,408.7632,409.3773,409.9912,410.6051,411.2188,411.8325,412.4460,413.0594,413.6727,414.2859,414.8990,415.5120,416.1248,416.7376,417.3502,417.9627,418.5751,419.1875,419.7997,420.4117,421.0237,421.6356,422.2473,422.8590,423.4705,424.0819,424.6932,425.3044,425.9155,426.5265,427.1374,427.7482,428.3588,428.9693,429.5798,430.1901,430.8003,431.4104,432.0204,432.6303,433.2401,433.8497,434.4592,435.0687,435.6780,436.2872,436.8963,437.5053,438.1142,438.7230,439.3317,439.9402,440.5486,441.1570,441.7652,442.3733,442.9814,443.5892,444.1970,444.8047,445.4123,446.0197,446.6270,447.2343,447.8414,448.4484,449.0553,449.6621,450.2688,450.8754,451.4819,452.0882,452.6945,453.3006,453.9066,454.5125,455.1183,455.7240,456.3296,456.9351,457.5405,458.1457,458.7509,459.3559,459.9608,460.5656,461.1703,461.7750,462.3795,462.9838,463.5881,464.1923,464.7963,465.4002,466.0041,466.6078,467.2114,467.8149,468.4183,469.0216,469.6248,470.2278,470.8307,471.4336,472.0363,472.6390,473.2415,473.8439,474.4462,475.0484,475.6505,476.2524,476.8542,477.4560,478.0576,478.6592,479.2606,479.8619,480.4631,481.0642,481.6652,482.2661,482.8668,483.4675,484.0680,484.6685,485.2688,485.8690,486.4691,487.0691,487.6690,488.2688,488.8684,489.4680,490.0674,490.6668,491.2660,491.8651,492.4641,493.0630,493.6619,494.2605,494.8591,495.4576,496.0559,496.6542,497.2523,497.8504,498.4483,499.0461,499.6438,500.2414,500.8389,501.4363,502.0335,502.6307,503.2278,503.8247,504.4215,505.0182,505.6149,506.2114,506.8078,507.4041,508.0002,508.5963,509.1923,509.7881,510.3839,510.9795,511.5750,512.1704,512.7657,513.3609,513.9560,514.5510,515.1459,515.7406,516.3353,516.9298,517.5243,518.1186,518.7128,519.3069,519.9009,520.4948,521.0886,521.6823,522.2758,522.8693,523.4626,524.0559,524.6490,525.2421,525.8350,526.4278,527.0204,527.6130,528.2056,528.7979,529.3902,529.9823,530.5744,531.1663,531.7581,532.3499,532.9415,533.5330,534.1244,534.7156,535.3068,535.8979,536.4889,537.0797,537.6705,538.2611,538.8516,539.4421,540.0323,540.6226,541.2126,541.8027,542.3925,542.9823,543.5720,544.1615,544.7510,545.3403,545.9295,546.5186,547.1077,547.6965,548.2853,548.8740,549.4626,550.0511,550.6395,551.2277,551.8159,552.4039,552.9918,553.5797,554.1674,554.7549,555.3425,555.9298,556.5171,557.1043,557.6913,558.2783,558.8652,559.4519,560.0385,560.6251,561.2115,561.7978,562.3840,562.9701,563.5561,564.1420,564.7277,565.3134,565.8989,566.4844,567.0697,567.6550,568.2401,568.8251,569.4100,569.9948,570.5795,571.1641,571.7485,572.3329,572.9172,573.5013,574.0853,574.6693,575.2531,575.8369,576.4205,577.0040,577.5873,578.1707,578.7538,579.3369,579.9199,580.5027,581.0855,581.6682,582.2507,582.8331,583.4154,583.9976,584.5797,585.1617,585.7437,586.3254,586.9071,587.4886,588.0701,588.6515,589.2327,589.8138,590.3949,590.9758,591.5566,592.1373,592.7180,593.2985,593.8788,594.4591,595.0392,595.6193,596.1993,596.7791,597.3589,597.9385,598.5181,599.0975,599.6768,600.2560,600.8351,601.4141,601.9930,602.5717,603.1504,603.7290,604.3074,604.8858,605.4641,606.0422,606.6202,607.1981,607.7759,608.3536,608.9312,609.5087,610.0861,610.6634,611.2405,611.8176,612.3945,612.9714,613.5482,614.1248,614.7013,615.2777,615.8541,616.4302,617.0063,617.5823,618.1583,618.7340,619.3097,619.8853,620.4607,621.0361,621.6113,622.1865,622.7615,623.3364,623.9112,624.4859,625.0605,625.6350,626.2094,626.7837,627.3578,627.9319,628.5059,629.0798,629.6535,630.2272,630.8007,631.3741,631.9474,632.5207,633.0937,633.6667,634.2397,634.8124,635.3851,635.9577,636.5302,637.1025,637.6748,638.2469,638.8190,639.3909,639.9628,640.5345,641.1061,641.6776,642.2490,642.8203,643.3915,643.9626,644.5336,645.1044,645.6752,646.2458,646.8164,647.3868,647.9572,648.5275,649.0976,649.6676,650.2375,650.8073,651.3770,651.9466,652.5161,653.0855,653.6548,654.2239,654.7930,655.3619,655.9308,656.4996,657.0682,657.6367,658.2051,658.7734,659.3417,659.9098,660.4778,661.0457,661.6135,662.1812,662.7487,663.3162,663.8835,664.4508,665.0180,665.5850,666.1520,666.7188,667.2855,667.8522,668.4187,668.9851,669.5514,670.1176,670.6837,671.2497,671.8156,672.3813,672.9470,673.5126,674.0780,674.6434,675.2086,675.7737,676.3388,676.9037,677.4685,678.0333,678.5978,679.1624,679.7267,680.2911,680.8552,681.4193,681.9833,682.5472,683.1110,683.6746,684.2382,684.8016,685.3649,685.9282,686.4913,687.0543,687.6172,688.1801,688.7427,689.3054,689.8679,690.4302,690.9926,691.5547,692.1168,692.6788,693.2406,693.8024,694.3640,694.9256,695.4870,696.0483,696.6096,697.1707,697.7318,698.2927,698.8535,699.4141,699.9747,700.5352,701.0956,701.6559,702.2161,702.7762,703.3361,703.8960,704.4557,705.0154,705.5750,706.1343,706.6937,707.2529,707.8121,708.3711,708.9300,709.4888,710.0475,710.6061,711.1646,711.7230,712.2812,712.8394,713.3975,713.9554,714.5133,715.0710,715.6287,716.1863,716.7437,717.3010,717.8583,718.4154,718.9724,719.5293,720.0861,720.6428,721.1995,721.7559,722.3123,722.8686,723.4248,723.9808,724.5368,725.0927,725.6484,726.2041,726.7596,727.3151,727.8704,728.4257,728.9808,729.5358,730.0908,730.6456,731.2003,731.7549,732.3094,732.8638,733.4181,733.9723,734.5264,735.0803,735.6342,736.1880,736.7416,737.2952,737.8486,738.4020,738.9553,739.5084,740.0614,740.6143,741.1672,741.7199,742.2725,742.8250,743.3774,743.9297,744.4819,745.0340,745.5860,746.1379,746.6897,747.2413,747.7929,748.3444,748.8958,749.4470,749.9982,750.5492,751.1002,751.6510,752.2017,752.7524,753.3029,753.8533,754.4036,754.9539,755.5040,756.0540,756.6039,757.1536,757.7034,758.2529,758.8024,759.3518,759.9011,760.4503,760.9993,761.5483,762.0971,762.6459,763.1945,763.7431,764.2915,764.8398,765.3881,765.9362,766.4843,767.0322,767.5800,768.1277,768.6753,769.2228,769.7702,770.3175,770.8647,771.4118,771.9587,772.5056,773.0524,773.5991,774.1457,774.6921,775.2385,775.7847,776.3309,776.8770,777.4229,777.9687,778.5145,779.0601,779.6057,780.1511,780.6964,781.2416,781.7867,782.3317,782.8766,783.4214,783.9661,784.5107,785.0552,785.5996,786.1439,786.6880,787.2321,787.7761,788.3199,788.8637,789.4074,789.9509,790.4944,791.0377,791.5810,792.1241,792.6672,793.2101,793.7529,794.2957,794.8383,795.3808,795.9232,796.4655,797.0078,797.5499,798.0919,798.6337,799.1755,799.7172,800.2589,800.8003,801.3417,801.8830,802.4241,802.9652,803.5062,804.0471,804.5878,805.1285,805.6690,806.2095,806.7498,807.2900,807.8302,808.3702,808.9102,809.4500,809.9897,810.5294,811.0689,811.6083,812.1476,812.6868,813.2260,813.7650,814.3038,814.8427,815.3813,815.9199,816.4584,816.9968,817.5351,818.0732,818.6113,819.1493,819.6872,820.2250,820.7626,821.3002,821.8376,822.3750,822.9122,823.4494,823.9865,824.5234,825.0602,825.5970,826.1336,826.6701,827.2065,827.7429,828.2791,828.8152,829.3513,829.8871,830.4230,830.9587,831.4943,832.0298,832.5652,833.1005,833.6357,834.1708,834.7057,835.2407,835.7754,836.3101,836.8447,837.3792,837.9135,838.4478,838.9819,839.5160,840.0500,840.5838,841.1176,841.6512,842.1848,842.7183,843.2516,843.7849,844.3179,844.8510,845.3839,845.9167,846.4495,846.9821,847.5146,848.0471,848.5794,849.1116,849.6437,850.1757,850.7076,851.2394,851.7711,852.3027,852.8342,853.3657,853.8969,854.4281,854.9592,855.4902,856.0211,856.5519,857.0825,857.6131,858.1436,858.6740,859.2042,859.7344,860.2645,860.7944,861.3243,861.8541,862.3837,862.9133,863.4427,863.9720,864.5013,865.0305,865.5595,866.0884,866.6173,867.1460,867.6747,868.2032,868.7316,869.2599,869.7882,870.3163,870.8443,871.3723,871.9001,872.4278,872.9554,873.4829,874.0103,874.5376,875.0648,875.5919,876.1190,876.6458,877.1726,877.6993,878.2260,878.7524,879.2788,879.8051,880.3313,880.8574,881.3834,881.9092,882.4350,882.9607,883.4863,884.0117,884.5371,885.0624,885.5875,886.1126,886.6376,887.1624,887.6872,888.2119,888.7364,889.2609,889.7852,890.3094,890.8336,891.3577,891.8817,892.4055,892.9292,893.4529,893.9764,894.4998,895.0232,895.5464,896.0695,896.5926,897.1155,897.6384,898.1611,898.6837,899.2062,899.7286,900.2510,900.7732,901.2953,901.8173,902.3392,902.8611,903.3828,903.9044,904.4259,904.9473,905.4686,905.9898,906.5109,907.0319,907.5529,908.0736,908.5944,909.1149,909.6354,910.1558,910.6761,911.1963,911.7164,912.2364,912.7563,913.2761,913.7958,914.3154,914.8348,915.3542,915.8735,916.3927,916.9117,917.4307,917.9496,918.4684,918.9871,919.5057,920.0241,920.5425,921.0608,921.5789,922.0970,922.6150,923.1328,923.6506,924.1683,924.6859,925.2033,925.7206,926.2379,926.7551,927.2722,927.7891,928.3060,928.8227,929.3394,929.8560,930.3724,930.8887,931.4050,931.9211,932.4372,932.9531,933.4690,933.9847,934.5004,935.0159,935.5314,936.0468,936.5620,937.0771,937.5922,938.1071,938.6219,939.1367,939.6513,940.1658,940.6803,941.1946,941.7089,942.2230,942.7371,943.2510,943.7648,944.2786,944.7922,945.3057,945.8192,946.3325,946.8457,947.3588,947.8719,948.3848,948.8976,949.4104,949.9230,950.4355,950.9479,951.4603,951.9725,952.4846,952.9966,953.5086,954.0204,954.5322,955.0438,955.5553,956.0667,956.5781,957.0892,957.6004,958.1114,958.6223,959.1332,959.6439,960.1545,960.6650,961.1754,961.6857,962.1960,962.7061,963.2161,963.7260,964.2358,964.7456,965.2552,965.7647,966.2741,966.7834,967.2927,967.8018,968.3108,968.8198,969.3286,969.8373,970.3459,970.8544,971.3629,971.8712,972.3794,972.8875,973.3955,973.9034,974.4113,974.9189,975.4266,975.9341,976.4415,976.9489,977.4561,977.9632,978.4702,978.9771,979.4839,979.9907,980.4973,981.0038,981.5102,982.0165,982.5228,983.0289,983.5349,984.0408,984.5466,985.0524,985.5580,986.0635,986.5689,987.0742,987.5795,988.0846,988.5896,989.0945,989.5994,990.1041,990.6087,991.1132,991.6177,992.1220,992.6262,993.1304,993.6344,994.1383,994.6422,995.1459,995.6495,996.1530,996.6564,997.1598,997.6630,998.1661,998.6692,999.1721,999.6749,1000.1777,1000.6803,1001.1829,1001.6853,1002.1876,1002.6899,1003.1920,1003.6940,1004.1960,1004.6978,1005.1996,1005.7012,1006.2028,1006.7042,1007.2056,1007.7068,1008.2079,1008.7090,1009.2099,1009.7108,1010.2115,1010.7122,1011.2127,1011.7132,1012.2135,1012.7137,1013.2139,1013.7140,1014.2139,1014.7138,1015.2136,1015.7132,1016.2128,1016.7122,1017.2116,1017.7109,1018.2100,1018.7090,1019.2080,1019.7069,1020.2057,1020.7043,1021.2029,1021.7014,1022.1998,1022.6980,1023.1962,1023.6943,1024.1923,1024.6901,1025.1879,1025.6855,1026.1831,1026.6807,1027.1780,1027.6753,1028.1725,1028.6696,1029.1665,1029.6635,1030.1603,1030.6569,1031.1534,1031.6500,1032.1464,1032.6427,1033.1389,1033.6350,1034.1310,1034.6268,1035.1227,1035.6184,1036.1140,1036.6095,1037.1049,1037.6002,1038.0955,1038.5906,1039.0856,1039.5804,1040.0753,1040.5699,1041.0646,1041.5591,1042.0536,1042.5479,1043.0421,1043.5363,1044.0303,1044.5242,1045.0179,1045.5117,1046.0054,1046.4989,1046.9923,1047.4857,1047.9789,1048.4720,1048.9651,1049.4580,1049.9509,1050.4436,1050.9363,1051.4288,1051.9213,1052.4137,1052.9059,1053.3981,1053.8901,1054.3821,1054.8739,1055.3657,1055.8574,1056.3489,1056.8405,1057.3318,1057.8230,1058.3142,1058.8053,1059.2963,1059.7871,1060.2780,1060.7687,1061.2592,1061.7498,1062.2401,1062.7303,1063.2206,1063.7107,1064.2007,1064.6906,1065.1804,1065.6700,1066.1597,1066.6492,1067.1385,1067.6279,1068.1171,1068.6062,1069.0952,1069.5842,1070.0730,1070.5618,1071.0503,1071.5388,1072.0273,1072.5156,1073.0039,1073.4921,1073.9801,1074.4680,1074.9558,1075.4436,1075.9313,1076.4188,1076.9062,1077.3936,1077.8809,1078.3680,1078.8551,1079.3420,1079.8289,1080.3157,1080.8024,1081.2889,1081.7754,1082.2617,1082.7480,1083.2343,1083.7203,1084.2063,1084.6921,1085.1780,1085.6637,1086.1493,1086.6348,1087.1201,1087.6055,1088.0907,1088.5758,1089.0608,1089.5457,1090.0305,1090.5153,1090.9999,1091.4844,1091.9687,1092.4531,1092.9374,1093.4215,1093.9055,1094.3895,1094.8733,1095.3571,1095.8407,1096.3242,1096.8077,1097.2910,1097.7743,1098.2574,1098.7406,1099.2235,1099.7064,1100.1891,1100.6719,1101.1544,1101.6368,1102.1193,1102.6016,1103.0837,1103.5658,1104.0479,1104.5297,1105.0115,1105.4932,1105.9749,1106.4563,1106.9377,1107.4191,1107.9003,1108.3813,1108.8624,1109.3434,1109.8241,1110.3049,1110.7855,1111.2661,1111.7465,1112.2268,1112.7070,1113.1873,1113.6672,1114.1472,1114.6271,1115.1068,1115.5865,1116.0660,1116.5455,1117.0249,1117.5042,1117.9834,1118.4625,1118.9414,1119.4203,1119.8992,1120.3778,1120.8564,1121.3350,1121.8134,1122.2916,1122.7699,1123.2479,1123.7260,1124.2039,1124.6818,1125.1594,1125.6371,1126.1146,1126.5920,1127.0693,1127.5466,1128.0238,1128.5009,1128.9778,1129.4546,1129.9314,1130.4081,1130.8846,1131.3611,1131.8375,1132.3137,1132.7899,1133.2660,1133.7421,1134.2179,1134.6937,1135.1694,1135.6450,1136.1205,1136.5959,1137.0713,1137.5465,1138.0216,1138.4966,1138.9716,1139.4463,1139.9211,1140.3958,1140.8702,1141.3447,1141.8191,1142.2933,1142.7675,1143.2416,1143.7155,1144.1893,1144.6631,1145.1368,1145.6104,1146.0839,1146.5573,1147.0305,1147.5038,1147.9768,1148.4498,1148.9227,1149.3955,1149.8683,1150.3408,1150.8134,1151.2858,1151.7582,1152.2303,1152.7025,1153.1746,1153.6465,1154.1183,1154.5901,1155.0618,1155.5333,1156.0048,1156.4761,1156.9474,1157.4186,1157.8896,1158.3606,1158.8315,1159.3024,1159.7729,1160.2437,1160.7141,1161.1846,1161.6548,1162.1250,1162.5952,1163.0652,1163.5352,1164.0050,1164.4747,1164.9443,1165.4138,1165.8833,1166.3527,1166.8219,1167.2911,1167.7601,1168.2291
])
f_sup_785_1250 = np.array([711.8393,712.4261,713.0128,713.5994,714.1860,714.7724,715.3587,715.9449,716.5311,717.1171,717.7030,718.2888,718.8746,719.4602,720.0457,720.6312,721.2165,721.8018,722.3869,722.9719,723.5569,724.1417,724.7264,725.3111,725.8956,726.4801,727.0645,727.6487,728.2328,728.8169,729.4009,729.9847,730.5685,731.1522,731.7357,732.3192,732.9026,733.4858,734.0690,734.6521,735.2350,735.8179,736.4007,736.9834,737.5660,738.1484,738.7308,739.3131,739.8953,740.4774,741.0594,741.6413,742.2231,742.8048,743.3864,743.9679,744.5493,745.1306,745.7118,746.2929,746.8740,747.4548,748.0356,748.6164,749.1970,749.7775,750.3579,750.9382,751.5185,752.0986,752.6786,753.2585,753.8384,754.4182,754.9978,755.5773,756.1567,756.7361,757.3154,757.8945,758.4736,759.0525,759.6313,760.2101,760.7888,761.3673,761.9458,762.5242,763.1024,763.6806,764.2587,764.8366,765.4145,765.9922,766.5699,767.1475,767.7250,768.3024,768.8797,769.4568,770.0339,770.6110,771.1879,771.7646,772.3413,772.9179,773.4944,774.0709,774.6472,775.2233,775.7995,776.3755,776.9514,777.5272,778.1030,778.6786,779.2541,779.8295,780.4048,780.9801,781.5552,782.1302,782.7052,783.2800,783.8548,784.4294,785.0040,785.5784,786.1528,786.7270,787.3011,787.8752,788.4492,789.0231,789.5968,790.1705,790.7441,791.3176,791.8909,792.4642,793.0374,793.6105,794.1835,794.7563,795.3291,795.9018,796.4744,797.0469,797.6193,798.1917,798.7639,799.3359,799.9080,800.4799,801.0517,801.6234,802.1950,802.7665,803.3380,803.9093,804.4805,805.0516,805.6227,806.1936,806.7645,807.3352,807.9059,808.4764,809.0469,809.6172,810.1875,810.7576,811.3277,811.8976,812.4675,813.0373,813.6070,814.1766,814.7460,815.3154,815.8847,816.4539,817.0229,817.5920,818.1608,818.7297,819.2983,819.8669,820.4355,821.0038,821.5722,822.1404,822.7085,823.2766,823.8444,824.4123,824.9800,825.5476,826.1152,826.6826,827.2499,827.8172,828.3843,828.9514,829.5183,830.0852,830.6519,831.2186,831.7852,832.3516,832.9180,833.4843,834.0504,834.6165,835.1825,835.7484,836.3141,836.8799,837.4454,838.0109,838.5764,839.1417,839.7068,840.2720,840.8370,841.4019,841.9667,842.5314,843.0960,843.6606,844.2250,844.7893,845.3536,845.9177,846.4818,847.0457,847.6095,848.1733,848.7369,849.3005,849.8640,850.4273,850.9905,851.5537,852.1168,852.6798,853.2427,853.8054,854.3681,854.9307,855.4932,856.0556,856.6179,857.1801,857.7422,858.3042,858.8661,859.4279,859.9897,860.5513,861.1128,861.6743,862.2355,862.7968,863.3579,863.9189,864.4799,865.0408,865.6015,866.1622,866.7227,867.2832,867.8436,868.4038,868.9640,869.5240,870.0840,870.6439,871.2037,871.7634,872.3230,872.8825,873.4419,874.0012,874.5604,875.1195,875.6785,876.2374,876.7963,877.3550,877.9136,878.4721,879.0306,879.5889,880.1471,880.7053,881.2633,881.8213,882.3792,882.9369,883.4946,884.0521,884.6096,885.1669,885.7242,886.2814,886.8385,887.3954,887.9524,888.5092,889.0659,889.6224,890.1790,890.7354,891.2917,891.8479,892.4040,892.9600,893.5160,894.0718,894.6276,895.1832,895.7387,896.2942,896.8495,897.4048,897.9599,898.5150,899.0699,899.6248,900.1796,900.7343,901.2888,901.8433,902.3977,902.9520,903.5062,904.0603,904.6143,905.1682,905.7220,906.2758,906.8293,907.3829,907.9363,908.4896,909.0428,909.5960,910.1490,910.7020,911.2548,911.8076,912.3603,912.9128,913.4653,914.0176,914.5699,915.1221,915.6742,916.2262,916.7781,917.3298,917.8816,918.4332,918.9847,919.5361,920.0874,920.6386,921.1898,921.7408,922.2917,922.8425,923.3932,923.9439,924.4944,925.0449,925.5953,926.1455,926.6957,927.2457,927.7957,928.3456,928.8954,929.4451,929.9946,930.5441,931.0936,931.6428,932.1921,932.7411,933.2902,933.8391,934.3879,934.9366,935.4853,936.0338,936.5823,937.1306,937.6788,938.2270,938.7751,939.3230,939.8709,940.4186,940.9663,941.5139,942.0614,942.6088,943.1561,943.7032,944.2504,944.7974,945.3443,945.8911,946.4378,946.9844,947.5309,948.0774,948.6237,949.1700,949.7161,950.2621,950.8081,951.3540,951.8997,952.4454,952.9910,953.5364,954.0818,954.6271,955.1723,955.7174,956.2624,956.8073,957.3521,957.8969,958.4415,958.9860,959.5304,960.0747,960.6190,961.1631,961.7072,962.2511,962.7950,963.3387,963.8824,964.4260,964.9694,965.5128,966.0561,966.5992,967.1423,967.6854,968.2283,968.7711,969.3138,969.8564,970.3989,970.9413,971.4836,972.0259,972.5681,973.1101,973.6520,974.1939,974.7357,975.2773,975.8188,976.3604,976.9017,977.4430,977.9842,978.5253,979.0663,979.6072,980.1480,980.6887,981.2293,981.7698,982.3103,982.8506,983.3909,983.9310,984.4710,985.0110,985.5508,986.0906,986.6302,987.1699,987.7093,988.2487,988.7880,989.3271,989.8663,990.4053,990.9442,991.4830,992.0217,992.5603,993.0989,993.6373,994.1756,994.7139,995.2520,995.7900,996.3280,996.8659,997.4036,997.9413,998.4789,999.0164,999.5538,1000.0911,1000.6282,1001.1653,1001.7024,1002.2393,1002.7761,1003.3128,1003.8494,1004.3860,1004.9224,1005.4587,1005.9950,1006.5312,1007.0673,1007.6032,1008.1391,1008.6749,1009.2105,1009.7461,1010.2816,1010.8170,1011.3523,1011.8875,1012.4226,1012.9576,1013.4926,1014.0274,1014.5621,1015.0968,1015.6313,1016.1658,1016.7001,1017.2344,1017.7686,1018.3026,1018.8366,1019.3705,1019.9043,1020.4380,1020.9716,1021.5051,1022.0385,1022.5718,1023.1050,1023.6382,1024.1711,1024.7041,1025.2369,1025.7698,1026.3024,1026.8350,1027.3674,1027.8998,1028.4320,1028.9642,1029.4963,1030.0283,1030.5602,1031.0920,1031.6238,1032.1554,1032.6869,1033.2183,1033.7496,1034.2809,1034.8120,1035.3430,1035.8740,1036.4049,1036.9357,1037.4663,1037.9969,1038.5273,1039.0577,1039.5880,1040.1183,1040.6483,1041.1783,1041.7083,1042.2382,1042.7678,1043.2975,1043.8270,1044.3564,1044.8859,1045.4150,1045.9442,1046.4733,1047.0023,1047.5311,1048.0599,1048.5886,1049.1173,1049.6458,1050.1742,1050.7025,1051.2307,1051.7588,1052.2869,1052.8148,1053.3427,1053.8704,1054.3981,1054.9257,1055.4531,1055.9805,1056.5078,1057.0349,1057.5620,1058.0891,1058.6160,1059.1428,1059.6694,1060.1962,1060.7227,1061.2490,1061.7754,1062.3016,1062.8278,1063.3539,1063.8799,1064.4058,1064.9315,1065.4572,1065.9828,1066.5083,1067.0337,1067.5590,1068.0842,1068.6093,1069.1343,1069.6593,1070.1841,1070.7089,1071.2335,1071.7581,1072.2825,1072.8069,1073.3312,1073.8553,1074.3794,1074.9034,1075.4274,1075.9512,1076.4749,1076.9985,1077.5220,1078.0454,1078.5687,1079.0920,1079.6151,1080.1382,1080.6613,1081.1841,1081.7068,1082.2295,1082.7521,1083.2747,1083.7970,1084.3193,1084.8416,1085.3636,1085.8856,1086.4076,1086.9294,1087.4512,1087.9729,1088.4944,1089.0159,1089.5372,1090.0585,1090.5797,1091.1008,1091.6218,1092.1427,1092.6635,1093.1842,1093.7048,1094.2253,1094.7458,1095.2661,1095.7864,1096.3065,1096.8267,1097.3466,1097.8665,1098.3862,1098.9059,1099.4255,1099.9451,1100.4645,1100.9838,1101.5029,1102.0221,1102.5411,1103.0601,1103.5790,1104.0977,1104.6163,1105.1349,1105.6534,1106.1718,1106.6901,1107.2083,1107.7263,1108.2444,1108.7623,1109.2802,1109.7979,1110.3154,1110.8330,1111.3505,1111.8678,1112.3850,1112.9022,1113.4193,1113.9363,1114.4531,1114.9700,1115.4867,1116.0033,1116.5198,1117.0363,1117.5526,1118.0688,1118.5850,1119.1010,1119.6169,1120.1328,1120.6486,1121.1643,1121.6798,1122.1953,1122.7107,1123.2261,1123.7412,1124.2563,1124.7714,1125.2864,1125.8011,1126.3159,1126.8306,1127.3451,1127.8596,1128.3740,1128.8883,1129.4025,1129.9165,1130.4305,1130.9445,1131.4583,1131.9720,1132.4856,1132.9991,1133.5126,1134.0260,1134.5392,1135.0524,1135.5654,1136.0785,1136.5913,1137.1041,1137.6168,1138.1294,1138.6420,1139.1544,1139.6667,1140.1790,1140.6910,1141.2031,1141.7151,1142.2269,1142.7388,1143.2504,1143.7620,1144.2734,1144.7849,1145.2963,1145.8074,1146.3186,1146.8296,1147.3405,1147.8513,1148.3621,1148.8728,1149.3833,1149.8938,1150.4042,1150.9144,1151.4247,1151.9348,1152.4448,1152.9547,1153.4646,1153.9742,1154.4839,1154.9935,1155.5029,1156.0123,1156.5216,1157.0308,1157.5398,1158.0488,1158.5577,1159.0665,1159.5752,1160.0839,1160.5924,1161.1008,1161.6091,1162.1174,1162.6256,1163.1337,1163.6416,1164.1495,1164.6573,1165.1650,1165.6726,1166.1802,1166.6875,1167.1948,1167.7021,1168.2092,1168.7163,1169.2233,1169.7301,1170.2369,1170.7435,1171.2501,1171.7567,1172.2631,1172.7694,1173.2756,1173.7817,1174.2877,1174.7937,1175.2996,1175.8053,1176.3109,1176.8165,1177.3220,1177.8274,1178.3328,1178.8379,1179.3430,1179.8480,1180.3529,1180.8578,1181.3625,1181.8672,1182.3717,1182.8762,1183.3806,1183.8849,1184.3890,1184.8932,1185.3972,1185.9011,1186.4049,1186.9086,1187.4122,1187.9158,1188.4193,1188.9226,1189.4259,1189.9291,1190.4321,1190.9352,1191.4380,1191.9408,1192.4436,1192.9462,1193.4487,1193.9512,1194.4535,1194.9558,1195.4579,1195.9600,1196.4619,1196.9639,1197.4657,1197.9674,1198.4690,1198.9705,1199.4719,1199.9733,1200.4745,1200.9757,1201.4767,1201.9777,1202.4785,1202.9794,1203.4800,1203.9806,1204.4811,1204.9816,1205.4819,1205.9821,1206.4823,1206.9823,1207.4823,1207.9822,1208.4819,1208.9816,1209.4812,1209.9807,1210.4801,1210.9794,1211.4786,1211.9778,1212.4768,1212.9757,1213.4746,1213.9734,1214.4720,1214.9706,1215.4691,1215.9675,1216.4658,1216.9640,1217.4622,1217.9602,1218.4581,1218.9559,1219.4537,1219.9514,1220.4490,1220.9464,1221.4438,1221.9412,1222.4384,1222.9354,1223.4325,1223.9293,1224.4263,1224.9230,1225.4197,1225.9161,1226.4127,1226.9091,1227.4054,1227.9015,1228.3976,1228.8937,1229.3895,1229.8854,1230.3811,1230.8768,1231.3723,1231.8678,1232.3632,1232.8585,1233.3536,1233.8488,1234.3437,1234.8387,1235.3335,1235.8282,1236.3229,1236.8175,1237.3119,1237.8063,1238.3005,1238.7948,1239.2888,1239.7828,1240.2767,1240.7706,1241.2643,1241.7579,1242.2515,1242.7450,1243.2384,1243.7316,1244.2249,1244.7179,1245.2109,1245.7039,1246.1967,1246.6893,1247.1820,1247.6746,1248.1670,1248.6593,1249.1516,1249.6438,1250.1359,1250.6279,1251.1198,1251.6116,1252.1033,1252.5950,1253.0865,1253.5780,1254.0693,1254.5605,1255.0518,1255.5428,1256.0338,1256.5248,1257.0155,1257.5062,1257.9969,1258.4874,1258.9779,1259.4683,1259.9585,1260.4487,1260.9387,1261.4288,1261.9187,1262.4084,1262.8982,1263.3878,1263.8773,1264.3668,1264.8562,1265.3455,1265.8346,1266.3237,1266.8127,1267.3016,1267.7904,1268.2792,1268.7678,1269.2563,1269.7448,1270.2332,1270.7214,1271.2096,1271.6976,1272.1857,1272.6736,1273.1614,1273.6490,1274.1367,1274.6243,1275.1117,1275.5990,1276.0863,1276.5735,1277.0605,1277.5476,1278.0344,1278.5212,1279.0081,1279.4946,1279.9812,1280.4677,1280.9540,1281.4403,1281.9264,1282.4125,1282.8986,1283.3844,1283.8702,1284.3560,1284.8416,1285.3271,1285.8126,1286.2980,1286.7832,1287.2684,1287.7535,1288.2385,1288.7234,1289.2083,1289.6930,1290.1776,1290.6621,1291.1466,1291.6310,1292.1152,1292.5995,1293.0835,1293.5675,1294.0515,1294.5353,1295.0190,1295.5027,1295.9862,1296.4697,1296.9530,1297.4363,1297.9196,1298.4026,1298.8856,1299.3685,1299.8514,1300.3341,1300.8168,1301.2993,1301.7817,1302.2642,1302.7465,1303.2286,1303.7108,1304.1927,1304.6747,1305.1565,1305.6383,1306.1200,1306.6016,1307.0830,1307.5643,1308.0457,1308.5269,1309.0079,1309.4890,1309.9700,1310.4508,1310.9315,1311.4122,1311.8927,1312.3733,1312.8536,1313.3340,1313.8141,1314.2943,1314.7743,1315.2543,1315.7341,1316.2139,1316.6935,1317.1731,1317.6526,1318.1320,1318.6113,1319.0906,1319.5697,1320.0487,1320.5276,1321.0065,1321.4852,1321.9640,1322.4425,1322.9210,1323.3994,1323.8778,1324.3560,1324.8341,1325.3121,1325.7902,1326.2681,1326.7458,1327.2235,1327.7010,1328.1786,1328.6560,1329.1333,1329.6106,1330.0878,1330.5648,1331.0417,1331.5187,1331.9955,1332.4722,1332.9487,1333.4253,1333.9017,1334.3781,1334.8542,1335.3304,1335.8065,1336.2825,1336.7584,1337.2343,1337.7100,1338.1855,1338.6611,1339.1365,1339.6118,1340.0872,1340.5623,1341.0374,1341.5125,1341.9873,1342.4622,1342.9369,1343.4115,1343.8860,1344.3605,1344.8348,1345.3091,1345.7833,1346.2574,1346.7314,1347.2053,1347.6792,1348.1530,1348.6266,1349.1001,1349.5736,1350.0470,1350.5203,1350.9934,1351.4666,1351.9396,1352.4126,1352.8854,1353.3582,1353.8308,1354.3033,1354.7759,1355.2483,1355.7206,1356.1927,1356.6649,1357.1370,1357.6089,1358.0808,1358.5525,1359.0242,1359.4958,1359.9673,1360.4387,1360.9100,1361.3812,1361.8524,1362.3235,1362.7944,1363.2653,1363.7361,1364.2068,1364.6774,1365.1479,1365.6184,1366.0887,1366.5590,1367.0292,1367.4991,1367.9691,1368.4391,1368.9088,1369.3785,1369.8483,1370.3177,1370.7872,1371.2566,1371.7258,1372.1949,1372.6641,1373.1331,1373.6021,1374.0708,1374.5396,1375.0082,1375.4768,1375.9452,1376.4136,1376.8820,1377.3501,1377.8182,1378.2863,1378.7542,1379.2220,1379.6898,1380.1575,1380.6250,1381.0925,1381.5599,1382.0272,1382.4944,1382.9615,1383.4286,1383.8955,1384.3624,1384.8292,1385.2959,1385.7625,1386.2290,1386.6954,1387.1617,1387.6279,1388.0941,1388.5602,1389.0261,1389.4921,1389.9578,1390.4236,1390.8892,1391.3547,1391.8201,1392.2855,1392.7507,1393.2159,1393.6810,1394.1460,1394.6108,1395.0757,1395.5404,1396.0051,1396.4696,1396.9341,1397.3984,1397.8628,1398.3269,1398.7910,1399.2551,1399.7190,1400.1829,1400.6466,1401.1102,1401.5739,1402.0374,1402.5007,1402.9640,1403.4272,1403.8904,1404.3534,1404.8164,1405.2793,1405.7421,1406.2047,1406.6674,1407.1299,1407.5923,1408.0546,1408.5168,1408.9790,1409.4410,1409.9031,1410.3650,1410.8268,1411.2885,1411.7501,1412.2117,1412.6731,1413.1344,1413.5957,1414.0569,1414.5179,1414.9790,1415.4399,1415.9008,1416.3615,1416.8221,1417.2827,1417.7432,1418.2035,1418.6638,1419.1240,1419.5842,1420.0442,1420.5042,1420.9640,1421.4238,1421.8834,1422.3430,1422.8026,1423.2620,1423.7213,1424.1805,1424.6396,1425.0988,1425.5577,1426.0166,1426.4755,1426.9341,1427.3927,1427.8513,1428.3097,1428.7681,1429.2263,1429.6844,1430.1426,1430.6006,1431.0585,1431.5164,1431.9741,1432.4318,1432.8893,1433.3468,1433.8042,1434.2615,1434.7186,1435.1758,1435.6328,1436.0897,1436.5466,1437.0034,1437.4601,1437.9166,1438.3732,1438.8296,1439.2859,1439.7421,1440.1982,1440.6543,1441.1104,1441.5662,1442.0220,1442.4777,1442.9333,1443.3889,1443.8444,1444.2997,1444.7550,1445.2101,1445.6653,1446.1202,1446.5752,1447.0300,1447.4847,1447.9393,1448.3939,1448.8484,1449.3029,1449.7571,1450.2113,1450.6655,1451.1195,1451.5735,1452.0273,1452.4811,1452.9348,1453.3884,1453.8419,1454.2953,1454.7487,1455.2019,1455.6550,1456.1082,1456.5612,1457.0140,1457.4668,1457.9196,1458.3722,1458.8247,1459.2772,1459.7296,1460.1819,1460.6340,1461.0862,1461.5382,1461.9901,1462.4420,1462.8937,1463.3455,1463.7970,1464.2485,1464.6998,1465.1512,1465.6024,1466.0536,1466.5046,1466.9556,1467.4065,1467.8573,1468.3080,1468.7587,1469.2091,1469.6595,1470.1100,1470.5602,1471.0104,1471.4604,1471.9105,1472.3605,1472.8103,1473.2600,1473.7096,1474.1592,1474.6086,1475.0581,1475.5074,1475.9567,1476.4058,1476.8547,1477.3037,1477.7526,1478.2014,1478.6501,1479.0988,1479.5472,1479.9956,1480.4440,1480.8922,1481.3405,1481.7885,1482.2365,1482.6844,1483.1322,1483.5800,1484.0276,1484.4752,1484.9226,1485.3700,1485.8174,1486.2645,1486.7117,1487.1587,1487.6056,1488.0525,1488.4993,1488.9459,1489.3926,1489.8391,1490.2855,1490.7318,1491.1781,1491.6243,1492.0703,1492.5164,1492.9623,1493.4081,1493.8538,1494.2994,1494.7450,1495.1904,1495.6359,1496.0811,1496.5264,1496.9714,1497.4165,1497.8615,1498.3063,1498.7510,1499.1957,1499.6403,1500.0848,1500.5293,1500.9736,1501.4178,1501.8619,1502.3060,1502.7500,1503.1940,1503.6378,1504.0815,1504.5251,1504.9686,1505.4121,1505.8555,1506.2988,1506.7421,1507.1852,1507.6282,1508.0712,1508.5139,1508.9568,1509.3994,1509.8420,1510.2845,1510.7269,1511.1693,1511.6116,1512.0537,1512.4957,1512.9377,1513.3796,1513.8215,1514.2632,1514.7048,1515.1464,1515.5879,1516.0293,1516.4706,1516.9117,1517.3529,1517.7939,1518.2349,1518.6758,1519.1165,1519.5573,1519.9978,1520.4384,1520.8788,1521.3191,1521.7594,1522.1995,1522.6396,1523.0796,1523.5195,1523.9594,1524.3990,1524.8387,1525.2783,1525.7178,1526.1571,1526.5964,1527.0356,1527.4747,1527.9138,1528.3528,1528.7916,1529.2305,1529.6691,1530.1078,1530.5463,1530.9847,1531.4231,1531.8613,1532.2994,1532.7375,1533.1755,1533.6135,1534.0514,1534.4891,1534.9268,1535.3644,1535.8018,1536.2393,1536.6765,1537.1138,1537.5509,1537.9879,1538.4249,1538.8618,1539.2986,1539.7354,1540.1720,1540.6085,1541.0449,1541.4813,1541.9176,1542.3538,1542.7899,1543.2258,1543.6619,1544.0977,1544.5334,1544.9691,1545.4047,1545.8402,1546.2756,1546.7109,1547.1462,1547.5813,1548.0165,1548.4514,1548.8864,1549.3212,1549.7559,1550.1904,1550.6250,1551.0596,1551.4939,1551.9282,1552.3624,1552.7965,1553.2306,1553.6646,1554.0984,1554.5322,1554.9658,1555.3994,1555.8330,1556.2665,1556.6998,1557.1331,1557.5663,1557.9993,1558.4324,1558.8652,1559.2981,1559.7308,1560.1635,1560.5961,1561.0286,1561.4609,1561.8933,1562.3256,1562.7577,1563.1897,1563.6217,1564.0536,1564.4854,1564.9171,1565.3488,1565.7803,1566.2118,1566.6432,1567.0745,1567.5056,1567.9368,1568.3678,1568.7987,1569.2296,1569.6604,1570.0911,1570.5216,1570.9521,1571.3826,1571.8130,1572.2432,1572.6733,1573.1035,1573.5334,1573.9634,1574.3932,1574.8230,1575.2527,1575.6823,1576.1117,1576.5411,1576.9705,1577.3997,1577.8289,1578.2578,1578.6869,1579.1157,1579.5446,1579.9733,1580.4019,1580.8304,1581.2589,1581.6873,1582.1156,1582.5438,1582.9719,1583.3999,1583.8279,1584.2557,1584.6835,1585.1112,1585.5388,1585.9663,1586.3938,1586.8212,1587.2484,1587.6755,1588.1027,1588.5297,1588.9565,1589.3834,1589.8102,1590.2368,1590.6635,1591.0900,1591.5164,1591.9426,1592.3689,1592.7950,1593.2212,1593.6471,1594.0730,1594.4989,1594.9246,1595.3502,1595.7758,1596.2013,1596.6266,1597.0520,1597.4772,1597.9023,1598.3274,1598.7523,1599.1772,1599.6019,1600.0267,1600.4513,1600.8759,1601.3003,1601.7246,1602.1489,1602.5731,1602.9972,1603.4213,1603.8452,1604.2690,1604.6929,1605.1166,1605.5402,1605.9636,1606.3871,1606.8104,1607.2336,1607.6569,1608.0800,1608.5029,1608.9259,1609.3488,1609.7715,1610.1941,1610.6167,1611.0392,1611.4615,1611.8839,1612.3062,1612.7283,1613.1504,1613.5724,1613.9943,1614.4161,1614.8378,1615.2595,1615.6810,1616.1025,1616.5239,1616.9452,1617.3665,1617.7876,1618.2086,1618.6295,1619.0504,1619.4713,1619.8920,1620.3126,1620.7332,1621.1536,1621.5740,1621.9943,1622.4144,1622.8346,1623.2546,1623.6746,1624.0945,1624.5142,1624.9340,1625.3535,1625.7731,1626.1925,1626.6118,1627.0311,1627.4503,1627.8694,1628.2885,1628.7074,1629.1262,1629.5449,1629.9636,1630.3822,1630.8008,1631.2191,1631.6375,1632.0558,1632.4740,1632.8920,1633.3101,1633.7279,1634.1458,1634.5635,1634.9812,1635.3988,1635.8163,1636.2336,1636.6510,1637.0682,1637.4854,1637.9025,1638.3195,1638.7363,1639.1532,1639.5699,1639.9866,1640.4032,1640.8196,1641.2361,1641.6523,1642.0686,1642.4847,1642.9008,1643.3168,1643.7327,1644.1484,1644.5642,1644.9799,1645.3954,1645.8108,1646.2262,1646.6415,1647.0568,1647.4719,1647.8870,1648.3019,1648.7168,1649.1316,1649.5463,1649.9609,1650.3755,1650.7899,1651.2042,1651.6185,1652.0327,1652.4469,1652.8610,1653.2749,1653.6887,1654.1025,1654.5162,1654.9298,1655.3434,1655.7568,1656.1702,1656.5835,1656.9967,1657.4098,1657.8229,1658.2357,1658.6487,1659.0614,1659.4741,1659.8867,1660.2992,1660.7117,1661.1240,1661.5363,1661.9485,1662.3606,1662.7726,1663.1846,1663.5964,1664.0082,1664.4198,1664.8314,1665.2429,1665.6544,1666.0658,1666.4771,1666.8882,1667.2993,1667.7103,1668.1212,1668.5321,1668.9429,1669.3535,1669.7642,1670.1746,1670.5851,1670.9954,1671.4056,1671.8158,1672.2260,1672.6359,1673.0458,1673.4557,1673.8655,1674.2751,1674.6847,1675.0942,1675.5037,1675.9130,1676.3221,1676.7313,1677.1405,1677.5494,1677.9584,1678.3672,1678.7760,1679.1847,1679.5933,1680.0017,1680.4102,1680.8185,1681.2267,1681.6349,1682.0430,1682.4509,1682.8589,1683.2667,1683.6744,1684.0822,1684.4897,1684.8972,1685.3046,1685.7119,1686.1191,1686.5264,1686.9335,1687.3405,1687.7473,1688.1542,1688.5609,1688.9675,1689.3741,1689.7806,1690.1870,1690.5934,1690.9996,1691.4058,1691.8119,1692.2179,1692.6238,1693.0297,1693.4353,1693.8411,1694.2466,1694.6521,1695.0575,1695.4628,1695.8680,1696.2732,1696.6783,1697.0833,1697.4882,1697.8931
])
f_sup_785_1850 = np.array([1392.5853,1393.0836,1393.5818,1394.0800,1394.5780,1395.0759,1395.5737,1396.0715,1396.5692,1397.0668,1397.5643,1398.0618,1398.5592,1399.0564,1399.5537,1400.0508,1400.5479,1401.0448,1401.5416,1402.0385,1402.5352,1403.0317,1403.5283,1404.0248,1404.5211,1405.0175,1405.5137,1406.0098,1406.5057,1407.0017,1407.4977,1407.9934,1408.4891,1408.9847,1409.4803,1409.9758,1410.4712,1410.9666,1411.4617,1411.9569,1412.4519,1412.9469,1413.4418,1413.9366,1414.4313,1414.9260,1415.4205,1415.9150,1416.4094,1416.9037,1417.3979,1417.8921,1418.3862,1418.8801,1419.3740,1419.8679,1420.3617,1420.8553,1421.3489,1421.8424,1422.3358,1422.8291,1423.3224,1423.8156,1424.3086,1424.8016,1425.2946,1425.7874,1426.2802,1426.7728,1427.2654,1427.7578,1428.2502,1428.7427,1429.2349,1429.7271,1430.2191,1430.7112,1431.2031,1431.6949,1432.1868,1432.6785,1433.1700,1433.6615,1434.1530,1434.6443,1435.1356,1435.6268,1436.1179,1436.6089,1437.0999,1437.5907,1438.0815,1438.5723,1439.0629,1439.5533,1440.0438,1440.5342,1441.0245,1441.5146,1442.0049,1442.4949,1442.9849,1443.4747,1443.9645,1444.4542,1444.9438,1445.4335,1445.9229,1446.4122,1446.9016,1447.3907,1447.8799,1448.3690,1448.8579,1449.3469,1449.8357,1450.3245,1450.8131,1451.3016,1451.7902,1452.2786,1452.7668,1453.2551,1453.7432,1454.2313,1454.7192,1455.2072,1455.6951,1456.1827,1456.6704,1457.1581,1457.6455,1458.1329,1458.6202,1459.1075,1459.5947,1460.0818,1460.5688,1461.0558,1461.5426,1462.0293,1462.5160,1463.0027,1463.4891,1463.9756,1464.4619,1464.9482,1465.4344,1465.9205,1466.4065,1466.8925,1467.3783,1467.8641,1468.3499,1468.8354,1469.3210,1469.8064,1470.2919,1470.7771,1471.2623,1471.7474,1472.2325,1472.7174,1473.2024,1473.6871,1474.1719,1474.6565,1475.1410,1475.6255,1476.1099,1476.5942,1477.0785,1477.5626,1478.0466,1478.5306,1479.0145,1479.4984,1479.9821,1480.4657,1480.9493,1481.4329,1481.9163,1482.3995,1482.8828,1483.3660,1483.8490,1484.3320,1484.8149,1485.2979,1485.7805,1486.2633,1486.7458,1487.2284,1487.7108,1488.1931,1488.6754,1489.1576,1489.6396,1490.1217,1490.6036,1491.0856,1491.5673,1492.0490,1492.5306,1493.0121,1493.4935,1493.9750,1494.4563,1494.9375,1495.4186,1495.8997,1496.3806,1496.8615,1497.3423,1497.8230,1498.3036,1498.7842,1499.2646,1499.7450,1500.2253,1500.7056,1501.1857,1501.6658,1502.1458,1502.6256,1503.1055,1503.5852,1504.0649,1504.5444,1505.0239,1505.5034,1505.9827,1506.4619,1506.9412,1507.4202,1507.8992,1508.3782,1508.8569,1509.3357,1509.8145,1510.2930,1510.7715,1511.2500,1511.7284,1512.2067,1512.6848,1513.1630,1513.6410,1514.1189,1514.5968,1515.0746,1515.5522,1516.0299,1516.5074,1516.9849,1517.4623,1517.9396,1518.4167,1518.8939,1519.3710,1519.8479,1520.3248,1520.8016,1521.2783,1521.7550,1522.2316,1522.7080,1523.1844,1523.6608,1524.1370,1524.6132,1525.0892,1525.5652,1526.0411,1526.5170,1526.9927,1527.4684,1527.9440,1528.4194,1528.8949,1529.3702,1529.8456,1530.3207,1530.7958,1531.2709,1531.7457,1532.2206,1532.6954,1533.1702,1533.6448,1534.1193,1534.5937,1535.0681,1535.5424,1536.0166,1536.4907,1536.9647,1537.4387,1537.9126,1538.3864,1538.8601,1539.3337,1539.8074,1540.2808,1540.7542,1541.2275,1541.7008,1542.1740,1542.6470,1543.1200,1543.5929,1544.0657,1544.5385,1545.0111,1545.4838,1545.9562,1546.4287,1546.9010,1547.3733,1547.8455,1548.3175,1548.7896,1549.2615,1549.7334,1550.2051,1550.6769,1551.1484,1551.6200,1552.0914,1552.5627,1553.0341,1553.5052,1553.9764,1554.4475,1554.9185,1555.3893,1555.8601,1556.3308,1556.8015,1557.2721,1557.7426,1558.2129,1558.6832,1559.1534,1559.6237,1560.0937,1560.5637,1561.0336,1561.5034,1561.9733,1562.4429,1562.9125,1563.3820,1563.8514,1564.3208,1564.7900,1565.2592,1565.7283,1566.1974,1566.6663,1567.1351,1567.6039,1568.0726,1568.5413,1569.0098,1569.4783,1569.9467,1570.4149,1570.8832,1571.3513,1571.8193,1572.2874,1572.7551,1573.2230,1573.6907,1574.1583,1574.6260,1575.0934,1575.5608,1576.0282,1576.4954,1576.9625,1577.4297,1577.8967,1578.3636,1578.8304,1579.2972,1579.7639,1580.2305,1580.6970,1581.1635,1581.6298,1582.0961,1582.5623,1583.0284,1583.4944,1583.9603,1584.4263,1584.8921,1585.3578,1585.8234,1586.2889,1586.7544,1587.2198,1587.6851,1588.1504,1588.6155,1589.0806,1589.5455,1590.0105,1590.4752,1590.9401,1591.4047,1591.8693,1592.3337,1592.7982,1593.2626,1593.7268,1594.1909,1594.6550,1595.1191,1595.5830,1596.0469,1596.5106,1596.9744,1597.4380,1597.9015,1598.3650,1598.8284,1599.2916,1599.7549,1600.2180,1600.6810,1601.1440,1601.6069,1602.0697,1602.5325,1602.9951,1603.4576,1603.9202,1604.3826,1604.8448,1605.3071,1605.7693,1606.2314,1606.6934,1607.1554,1607.6172,1608.0790,1608.5406,1609.0022,1609.4637,1609.9252,1610.3866,1610.8479,1611.3091,1611.7701,1612.2312,1612.6921,1613.1531,1613.6139,1614.0746,1614.5353,1614.9957,1615.4563,1615.9166,1616.3770,1616.8373,1617.2974,1617.7574,1618.2174,1618.6774,1619.1372,1619.5969,1620.0566,1620.5162,1620.9757,1621.4352,1621.8945,1622.3538,1622.8130,1623.2721,1623.7312,1624.1901,1624.6489,1625.1078,1625.5665,1626.0251,1626.4836,1626.9421,1627.4005,1627.8589,1628.3171,1628.7753,1629.2333,1629.6913,1630.1492,1630.6071,1631.0648,1631.5225,1631.9801,1632.4375,1632.8950,1633.3523,1633.8096,1634.2668,1634.7239,1635.1809,1635.6378,1636.0947,1636.5515,1637.0083,1637.4648,1637.9214,1638.3779,1638.8342,1639.2905,1639.7468,1640.2030,1640.6591,1641.1150,1641.5709,1642.0267,1642.4825,1642.9381,1643.3938,1643.8492,1644.3047,1644.7600,1645.2153,1645.6705,1646.1256,1646.5806,1647.0355,1647.4905,1647.9452,1648.3999,1648.8545,1649.3091,1649.7635,1650.2179,1650.6722,1651.1265,1651.5806,1652.0347,1652.4886,1652.9426,1653.3964,1653.8501,1654.3038,1654.7574,1655.2109,1655.6643,1656.1177,1656.5709,1657.0242,1657.4773,1657.9303,1658.3832,1658.8361,1659.2888,1659.7416,1660.1942,1660.6467,1661.0992,1661.5516,1662.0039,1662.4562,1662.9083,1663.3604,1663.8124,1664.2643,1664.7161,1665.1678,1665.6195,1666.0712,1666.5226,1666.9740,1667.4254,1667.8767,1668.3279,1668.7789,1669.2300,1669.6809,1670.1318,1670.5826,1671.0333,1671.4840,1671.9346,1672.3850,1672.8354,1673.2856,1673.7360,1674.1860,1674.6361,1675.0862,1675.5361,1675.9860,1676.4357,1676.8854,1677.3350,1677.7844,1678.2339,1678.6832,1679.1326,1679.5817,1680.0309,1680.4799,1680.9288,1681.3777,1681.8265,1682.2753,1682.7239,1683.1725,1683.6210,1684.0693,1684.5177,1684.9659,1685.4141,1685.8622,1686.3102,1686.7581,1687.2059,1687.6537,1688.1013,1688.5490,1688.9965,1689.4440,1689.8914,1690.3386,1690.7858,1691.2329,1691.6799,1692.1270,1692.5739,1693.0206,1693.4674,1693.9141,1694.3606,1694.8071,1695.2535,1695.6998,1696.1461,1696.5923,1697.0383,1697.4844,1697.9303,1698.3762,1698.8219,1699.2677,1699.7133,1700.1588,1700.6042,1701.0497,1701.4950,1701.9402,1702.3853,1702.8303,1703.2754,1703.7202,1704.1650,1704.6099,1705.0544,1705.4990,1705.9436,1706.3881,1706.8324,1707.2766,1707.7208,1708.1649,1708.6090,1709.0529,1709.4968,1709.9406,1710.3843,1710.8279,1711.2715,1711.7150,1712.1583,1712.6017,1713.0449,1713.4880,1713.9312,1714.3741,1714.8170,1715.2599,1715.7026,1716.1454,1716.5879,1717.0305,1717.4729,1717.9153,1718.3575,1718.7998,1719.2419,1719.6840,1720.1259,1720.5677,1721.0096,1721.4513,1721.8929,1722.3346,1722.7760,1723.2175,1723.6588,1724.1001,1724.5413,1724.9823,1725.4233,1725.8643,1726.3052,1726.7460,1727.1866,1727.6273,1728.0679,1728.5083,1728.9486,1729.3889,1729.8292,1730.2694,1730.7095,1731.1494,1731.5894,1732.0292,1732.4689,1732.9086,1733.3481,1733.7877,1734.2272,1734.6665,1735.1057,1735.5449,1735.9841,1736.4231,1736.8621,1737.3010,1737.7397,1738.1785,1738.6172,1739.0558,1739.4943,1739.9326,1740.3710,1740.8092,1741.2474,1741.6854,1742.1235,1742.5614,1742.9993,1743.4370,1743.8748,1744.3124,1744.7499,1745.1874,1745.6248,1746.0621,1746.4993,1746.9364,1747.3735,1747.8105,1748.2474,1748.6842,1749.1210,1749.5576,1749.9943,1750.4308,1750.8672,1751.3036,1751.7399,1752.1760,1752.6122,1753.0482,1753.4841,1753.9200,1754.3558,1754.7916,1755.2273,1755.6628,1756.0983,1756.5337,1756.9691,1757.4043,1757.8395,1758.2745,1758.7096,1759.1445,1759.5795,1760.0142,1760.4489,1760.8835,1761.3181,1761.7526,1762.1869,1762.6212,1763.0554,1763.4896,1763.9237,1764.3577,1764.7916,1765.2255,1765.6592,1766.0929,1766.5265,1766.9600,1767.3934,1767.8268,1768.2601,1768.6934,1769.1265,1769.5594,1769.9924,1770.4254,1770.8582,1771.2909,1771.7236,1772.1561,1772.5886,1773.0211,1773.4534,1773.8857,1774.3179,1774.7500,1775.1820,1775.6140,1776.0458,1776.4777,1776.9093,1777.3409,1777.7726,1778.2040,1778.6354,1779.0668,1779.4980,1779.9292,1780.3602,1780.7913,1781.2222,1781.6531,1782.0839,1782.5145,1782.9451,1783.3756,1783.8062,1784.2365,1784.6667,1785.0970,1785.5272,1785.9573,1786.3872,1786.8171,1787.2469,1787.6768,1788.1064,1788.5360,1788.9655,1789.3949,1789.8243,1790.2535,1790.6827,1791.1119,1791.5410,1791.9700,1792.3988,1792.8276,1793.2563,1793.6851,1794.1136,1794.5421,1794.9706,1795.3989,1795.8271,1796.2554,1796.6835,1797.1115,1797.5394,1797.9673,1798.3950,1798.8228,1799.2505,1799.6780,1800.1055,1800.5328,1800.9602,1801.3875,1801.8146,1802.2417,1802.6687,1803.0957,1803.5225,1803.9493,1804.3760,1804.8026,1805.2291,1805.6556,1806.0820,1806.5083,1806.9346,1807.3607,1807.7867,1808.2128,1808.6387,1809.0645,1809.4902,1809.9159,1810.3416,1810.7671,1811.1925,1811.6179,1812.0432,1812.4684,1812.8936,1813.3186,1813.7435,1814.1685,1814.5933,1815.0181,1815.4427,1815.8673,1816.2919,1816.7163,1817.1406,1817.5648,1817.9891,1818.4132,1818.8373,1819.2612,1819.6851,1820.1089,1820.5326,1820.9563,1821.3799,1821.8033,1822.2268,1822.6501,1823.0734,1823.4966,1823.9197,1824.3427,1824.7656,1825.1885,1825.6113,1826.0341,1826.4567,1826.8793,1827.3018,1827.7241,1828.1465,1828.5687,1828.9908,1829.4130,1829.8350,1830.2570,1830.6788,1831.1006,1831.5222,1831.9438,1832.3655,1832.7869,1833.2083,1833.6296,1834.0509,1834.4720,1834.8931,1835.3141,1835.7350,1836.1559,1836.5767,1836.9973,1837.4180,1837.8385,1838.2589,1838.6793,1839.0996,1839.5199,1839.9399,1840.3601,1840.7800,1841.2000,1841.6198,1842.0396,1842.4592,1842.8789,1843.2983,1843.7178,1844.1372,1844.5565,1844.9757,1845.3948,1845.8138,1846.2329,1846.6517,1847.0706,1847.4894,1847.9081,1848.3267,1848.7451,1849.1636,1849.5819,1850.0002,1850.4185,1850.8365,1851.2546,1851.6726,1852.0905,1852.5083,1852.9260,1853.3436,1853.7612,1854.1787,1854.5962,1855.0135,1855.4308,1855.8480,1856.2651,1856.6821,1857.0991,1857.5160,1857.9329,1858.3496,1858.7662,1859.1827,1859.5992,1860.0157,1860.4320,1860.8483,1861.2645,1861.6807,1862.0967,1862.5126,1862.9285,1863.3442,1863.7600,1864.1757,1864.5912,1865.0067,1865.4221,1865.8374,1866.2527,1866.6678,1867.0830,1867.4980,1867.9130,1868.3279,1868.7427,1869.1573,1869.5720,1869.9866,1870.4010,1870.8154,1871.2297,1871.6440,1872.0582,1872.4723,1872.8864,1873.3003,1873.7141,1874.1279,1874.5416,1874.9552,1875.3688,1875.7822,1876.1957,1876.6090,1877.0222,1877.4354,1877.8485,1878.2615,1878.6744,1879.0873,1879.5001,1879.9128,1880.3254,1880.7380,1881.1505,1881.5629,1881.9752,1882.3875,1882.7996,1883.2117,1883.6237,1884.0356,1884.4475,1884.8593,1885.2710,1885.6826,1886.0941,1886.5056,1886.9170,1887.3284,1887.7395,1888.1508,1888.5618,1888.9728,1889.3838,1889.7946,1890.2053,1890.6161,1891.0267,1891.4373,1891.8477,1892.2581,1892.6683,1893.0786,1893.4888,1893.8989,1894.3088,1894.7187,1895.1287,1895.5385,1895.9481,1896.3578,1896.7673,1897.1768,1897.5862,1897.9955,1898.4047,1898.8138,1899.2229,1899.6320,1900.0409,1900.4497,1900.8585,1901.2672,1901.6758,1902.0844,1902.4928,1902.9011,1903.3094,1903.7178,1904.1259,1904.5339,1904.9419,1905.3499,1905.7577,1906.1655,1906.5732,1906.9808,1907.3883,1907.7958,1908.2032,1908.6105,1909.0177,1909.4249,1909.8320,1910.2390,1910.6459,1911.0527,1911.4595,1911.8662,1912.2728,1912.6793,1913.0858,1913.4922,1913.8986,1914.3048,1914.7109,1915.1171,1915.5231,1915.9290,1916.3348,1916.7406,1917.1462,1917.5519,1917.9574,1918.3629,1918.7683,1919.1736,1919.5789,1919.9840,1920.3890,1920.7941,1921.1990,1921.6039,1922.0087,1922.4133,1922.8180,1923.2225,1923.6270,1924.0314,1924.4357,1924.8400,1925.2441,1925.6482,1926.0521,1926.4561,1926.8600,1927.2638,1927.6675,1928.0710,1928.4746,1928.8781,1929.2815,1929.6848,1930.0880,1930.4912,1930.8943,1931.2974,1931.7002,1932.1031,1932.5059,1932.9086,1933.3113,1933.7137,1934.1162,1934.5187,1934.9210,1935.3232,1935.7255,1936.1274,1936.5295,1936.9315,1937.3334,1937.7351,1938.1368,1938.5385,1938.9401,1939.3416,1939.7429,1940.1443,1940.5455,1940.9467,1941.3478,1941.7488,1942.1498,1942.5507,1942.9514,1943.3522,1943.7528,1944.1533,1944.5538,1944.9542,1945.3546,1945.7548,1946.1550,1946.5551,1946.9551,1947.3551,1947.7550,1948.1548,1948.5544,1948.9541,1949.3538,1949.7532,1950.1526,1950.5520,1950.9513,1951.3505,1951.7495,1952.1486,1952.5475,1952.9464,1953.3452,1953.7440,1954.1426,1954.5413,1954.9397,1955.3381,1955.7365,1956.1348,1956.5330,1956.9310,1957.3291,1957.7271,1958.1250,1958.5228,1958.9205,1959.3182,1959.7158,1960.1133,1960.5107,1960.9081,1961.3054,1961.7026,1962.0997,1962.4968,1962.8938,1963.2906,1963.6875,1964.0842,1964.4810,1964.8776,1965.2740,1965.6705,1966.0669,1966.4631,1966.8594,1967.2555,1967.6516,1968.0476,1968.4435,1968.8394,1969.2351,1969.6307,1970.0264,1970.4219,1970.8174,1971.2128,1971.6080,1972.0033,1972.3984,1972.7936,1973.1885,1973.5835,1973.9783,1974.3730,1974.7678,1975.1624,1975.5569,1975.9514,1976.3458,1976.7401,1977.1344,1977.5286,1977.9226,1978.3167,1978.7106,1979.1045,1979.4982,1979.8920,1980.2855,1980.6791,1981.0726,1981.4661,1981.8594,1982.2526,1982.6458,1983.0388,1983.4319,1983.8248,1984.2178,1984.6105,1985.0033,1985.3959,1985.7885,1986.1809,1986.5734,1986.9657,1987.3580,1987.7502,1988.1423,1988.5343,1988.9263,1989.3182,1989.7101,1990.1018,1990.4934,1990.8850,1991.2765,1991.6680,1992.0593,1992.4506,1992.8418,1993.2329,1993.6240,1994.0150,1994.4059,1994.7968,1995.1875,1995.5781,1995.9687,1996.3593,1996.7498,1997.1401,1997.5304,1997.9207,1998.3108,1998.7008,1999.0908,1999.4807,1999.8706,2000.2604,2000.6500,2001.0397,2001.4292,2001.8187,2002.2081,2002.5974,2002.9867,2003.3759,2003.7649,2004.1539,2004.5428,2004.9318,2005.3206,2005.7092,2006.0979,2006.4865,2006.8749,2007.2633,2007.6516,2008.0399,2008.4281,2008.8162,2009.2042,2009.5922,2009.9801,2010.3679,2010.7556,2011.1433,2011.5309,2011.9183,2012.3058,2012.6931,2013.0804,2013.4677,2013.8547,2014.2418,2014.6288,2015.0156,2015.4025,2015.7892,2016.1759,2016.5625,2016.9490,2017.3354,2017.7218,2018.1082,2018.4944,2018.8805,2019.2666,2019.6526,2020.0385,2020.4243,2020.8101,2021.1958,2021.5814,2021.9669,2022.3524,2022.7378,2023.1232,2023.5084,2023.8936,2024.2787,2024.6637,2025.0486,2025.4335,2025.8182,2026.2030,2026.5876,2026.9722,2027.3567,2027.7411,2028.1254,2028.5096,2028.8939,2029.2780,2029.6620,2030.0460,2030.4299,2030.8137,2031.1974,2031.5811,2031.9647,2032.3481,2032.7316,2033.1150,2033.4983,2033.8815,2034.2646,2034.6477,2035.0306,2035.4136,2035.7964,2036.1792,2036.5619,2036.9445,2037.3270,2037.7095,2038.0918,2038.4741,2038.8564,2039.2385,2039.6206,2040.0027,2040.3846,2040.7665,2041.1482,2041.5299,2041.9116,2042.2931,2042.6747,2043.0560,2043.4374,2043.8186,2044.1998,2044.5809,2044.9619,2045.3429,2045.7238,2046.1046,2046.4854,2046.8660,2047.2466,2047.6271,2048.0076,2048.3879,2048.7683,2049.1484,2049.5286,2049.9087,2050.2886,2050.6685,2051.0483,2051.4280,2051.8079,2052.1875,2052.5669,2052.9463,2053.3257,2053.7051,2054.0842,2054.4634,2054.8425,2055.2217,2055.6006,2055.9795,2056.3582,2056.7368,2057.1155,2057.4941,2057.8726,2058.2510,2058.6294,2059.0076,2059.3857,2059.7639,2060.1418,2060.5200,2060.8977,2061.2756,2061.6533,2062.0310,2062.4087,2062.7861,2063.1636,2063.5410,2063.9182,2064.2954,2064.6726,2065.0496,2065.4268,2065.8037,2066.1804,2066.5571,2066.9338,2067.3105,2067.6870,2068.0635,2068.4399,2068.8162,2069.1926,2069.5686,2069.9448,2070.3208,2070.6968,2071.0728,2071.4485,2071.8242,2072.1997,2072.5754,2072.9509,2073.3264,2073.7017,2074.0769,2074.4521,2074.8274,2075.2024,2075.5774,2075.9521,2076.3271,2076.7019,2077.0764,2077.4512,2077.8257,2078.2002,2078.5745,2078.9487,2079.3230,2079.6973,2080.0713,2080.4453,2080.8193,2081.1931,2081.5669,2081.9407,2082.3142,2082.6877,2083.0613,2083.4348,2083.8081,2084.1814,2084.5544,2084.9277,2085.3008,2085.6736,2086.0466,2086.4194,2086.7922,2087.1648,2087.5374,2087.9099,2088.2825,2088.6548,2089.0271,2089.3992,2089.7715,2090.1436,2090.5156,2090.8875,2091.2593,2091.6311,2092.0027,2092.3745,2092.7461,2093.1174,2093.4888,2093.8601,2094.2314,2094.6028,2094.9739,2095.3447,2095.7158,2096.0867,2096.4575,2096.8281,2097.1990,2097.5696,2097.9399,2098.3105,2098.6809,2099.0510,2099.4214,2099.7915,2100.1616,2100.5315,2100.9016,2101.2715,2101.6411,2102.0107,2102.3804,2102.7500,2103.1196,2103.4890,2103.8582,2104.2275,2104.5967,2104.9658,2105.3350,2105.7039,2106.0728,2106.4417,2106.8103,2107.1790,2107.5476,2107.9160,2108.2844,2108.6528,2109.0212,2109.3894,2109.7576,2110.1257,2110.4937,2110.8616,2111.2295,2111.5972,2111.9648,2112.3325,2112.7002,2113.0676,2113.4351,2113.8022,2114.1697,2114.5369,2114.9038,2115.2710,2115.6379,2116.0049,2116.3716,2116.7383,2117.1050,2117.4717,2117.8381,2118.2046,2118.5710,2118.9373,2119.3035,2119.6697,2120.0356,2120.4019,2120.7676,2121.1335,2121.4993,2121.8650,2122.2307,2122.5962,2122.9617,2123.3271,2123.6924,2124.0579,2124.4229,2124.7881,2125.1531,2125.5181,2125.8831,2126.2478,2126.6125,2126.9773,2127.3418,2127.7063,2128.0708,2128.4353,2128.7996,2129.1638,2129.5278,2129.8921,2130.2561,2130.6199,2130.9839,2131.3477,2131.7114,2132.0750,2132.4385,2132.8020,2133.1655,2133.5288,2133.8921,2134.2554,2134.6184,2134.9814,2135.3445,2135.7075,2136.0703,2136.4331,2136.7957,2137.1584,2137.5210,2137.8833,2138.2458,2138.6082,2138.9705,2139.3325,2139.6946,2140.0566,2140.4187,2140.7805,2141.1423,2141.5042,2141.8657,2142.2273,2142.5889,2142.9502,2143.3115,2143.6729,2144.0342,2144.3953,2144.7563,2145.1174,2145.4783,2145.8391,2146.2000,2146.5605,2146.9211,2147.2817,2147.6423,2148.0027,2148.3630,2148.7234,2149.0835,2149.4436,2149.8037,2150.1636,2150.5237,2150.8833,2151.2432,2151.6028,2151.9624,2152.3220,2152.6814,2153.0408,2153.4001,2153.7593,2154.1187,2154.4775,2154.8367,2155.1956,2155.5544,2155.9133,2156.2720,2156.6306,2156.9893,2157.3477,2157.7063,2158.0645,2158.4229,2158.7810,2159.1392,2159.4973,2159.8552,2160.2131,2160.5710,2160.9287,2161.2866,2161.6440,2162.0017,2162.3591,2162.7166,2163.0740,2163.4312,2163.7883,2164.1455,2164.5024,2164.8596,2165.2163,2165.5732,2165.9299,2166.2866,2166.6433,2166.9998,2167.3562,2167.7126,2168.0691,2168.4253,2168.7815,2169.1375,2169.4934,2169.8494,2170.2053,2170.5610,2170.9167,2171.2725,2171.6282,2171.9836,2172.3391,2172.6943,2173.0498,2173.4050,2173.7600,2174.1152,2174.4702,2174.8252,2175.1799,2175.5347,2175.8894,2176.2441,2176.5986,2176.9531,2177.3076,2177.6619,2178.0161,2178.3704,2178.7244,2179.0786,2179.4326,2179.7864,2180.1401,2180.4939,2180.8477,2181.2014,2181.5549,2181.9082,2182.2617,2182.6150,2182.9683,2183.3215,2183.6746,2184.0276,2184.3806,2184.7334,2185.0862,2185.4390,2185.7917,2186.1443,2186.4968,2186.8494,2187.2017,2187.5540,2187.9062,2188.2583,2188.6104,2188.9624,2189.3145,2189.6663,2190.0181,2190.3699,2190.7214,2191.0730,2191.4246,2191.7759,2192.1272,2192.4785,2192.8298,2193.1809,2193.5320,2193.8831,2194.2339,2194.5847,2194.9355,2195.2864,2195.6370,2195.9875,2196.3379,2196.6885,2197.0388,2197.3889,2197.7393,2198.0894,2198.4395,2198.7893,2199.1394,2199.4890,2199.8389,2200.1885,2200.5381,2200.8877,2201.2373,2201.5867,2201.9360,2202.2852,2202.6345,2202.9834,2203.3325,2203.6816,2204.0305,2204.3792,2204.7280,2205.0767,2205.4253,2205.7739,2206.1223,2206.4707,2206.8191,2207.1672,2207.5154,2207.8635,2208.2114,2208.5596,2208.9072,2209.2551,2209.6028,2209.9504,2210.2981,2210.6458,2210.9932,2211.3406,2211.6877,2212.0349,2212.3821,2212.7292,2213.0762,2213.4233,2213.7700,2214.1169,2214.4636,2214.8103,2215.1567,2215.5034,2215.8499,2216.1960,2216.5425,2216.8887,2217.2349,2217.5808,2217.9270,2218.2727,2218.6187,2218.9644,2219.3103,2219.6558,2220.0015,2220.3469,2220.6924,2221.0376,2221.3831,2221.7283,2222.0732,2222.4185,2222.7634,2223.1082,2223.4531,2223.7979,2224.1426,2224.4873,2224.8318,2225.1763,2225.5208,2225.8650,2226.2092,2226.5535,2226.8977,2227.2417,2227.5857,2227.9297,2228.2734,2228.6172,2228.9609,2229.3044,2229.6479,2229.9915,2230.3350
])

# %% [markdown]
# #### Background

# %%
f_sup_785_1850.shape
# Out:
# (2000,)

# %%
back_650 = rd.read_data("data/20221111 Indene Carbendazim 785 Raman/BG 2min ctr650.tif")

# %%
back_1250 = rd.read_data("data/20221111 Indene Carbendazim 785 Raman/BG 2min ctr1250.tif")

# %%
back_1850 = rd.read_data("data/20221111 Indene Carbendazim 785 Raman/BG 2min ctr1850.tif")

# %% [markdown]
# #### Indene

# %%
indene_650 = rd.read_data("data/20221111 Indene Carbendazim 785 Raman/Indene ctr650 2min 10x PlanN 32mW.tif")

# %%
indene_1250 = rd.read_data("data/20221111 Indene Carbendazim 785 Raman/Indene ctr1250 2min 10x PlanN 32mW.tif")

# %%
indene_1850 = rd.read_data("data/20221111 Indene Carbendazim 785 Raman/Indene ctr1850 2min 10x PlanN 32mW.tif")

# %% [markdown]
# #### Carbendazim Raman
#
# Pay attention that it is 2 min integration time. Probably for good comparison you will have to normalize it.

# %%
car_650 = rd.read_data("data/20221111 Indene Carbendazim 785 Raman/Cab ctr650 2min 10x PlanN 32mW.tif")

# %%
car_1250 = rd.read_data("data/20221111 Indene Carbendazim 785 Raman/Cab ctr1250 2min 10x PlanN 32mW.tif")

# %%
car_1850 = rd.read_data("data/20221111 Indene Carbendazim 785 Raman/Cab ctr1850 2min 10x PlanN 32mW.tif")

# %% [markdown]
# #### Background for Thiacloprid and Acetamiprid; 20 secs 4 avg

# %%
f_sup_background_20s_4avg = np.genfromtxt("data/20220816 Analyte 532 Raman/background20s_4avg.dat", delimiter=",")

# %%
background_20s_4avg = rd.read_data("data/20220816 Analyte 532 Raman/background 20s 4avg.tif")

# %%
f_sup_background_20s_4avg.shape
# Out:
# (1600,)

# %% [markdown]
# #### Thiacloprid Raman

# %%
thia_raman_20s = rd.read_data("data/20220816 Analyte 532 Raman/No2 Thiacloprid powder/20s 4avg 100um fiber HWP42 MR-Newton ctr1400.tif")

# %% [markdown]
# #### Acetamiprid Raman

# %%
aceta_raman_20s = rd.read_data("data/20220816 Analyte 532 Raman/No4 Acetamiprid powder/20s 4avg 100um fiber HWP42 MR-Newton ctr1400.tif")

# %% [markdown]
# ### Analytes SERS

# %%
f_sup_sers = np.genfromtxt("data/20220422 SERS data generation/wavenumber_support.dat", delimiter=",")

# %% [markdown]
# #### 1 - Carbendazim

# %%
car_batch1_3min_mapping = rd.read_data("data/20220422 SERS data generation/analyte 1/mapping50X50/1_3min_b3_50X50_spectral_mapping_1.tif")
car_batch2_3min_mapping = rd.read_data("data/20220422 SERS data generation/analyte 1/mapping50X50/1_3min_b3_50X50_spectral_mapping_2.tif")
car_batch3_3min_mapping = rd.read_data("data/20220422 SERS data generation/analyte 1/mapping50X50/1_3min_b3_50X50_spectral_mapping_3.tif")
# Out:
# ImageJ series: detected extra dimension 'I'
# ImageJ series: detected extra dimension 'I'
# ImageJ series: detected extra dimension 'I'

# %% [markdown]
# #### 2 - Thiacloprid

# %%
thia_batch1_3min_mapping = rd.read_data("data/20220421 SERS data generation/analyte 2/mapping 50X50/2_3min_b3_50X50_spectral_mapping_1.tif")
thia_batch2_3min_mapping = rd.read_data("data/20220421 SERS data generation/analyte 2/mapping 50X50/2_3min_b3_50X50_spectral_mapping_2.tif")
thia_batch3_3min_mapping = rd.read_data("data/20220421 SERS data generation/analyte 2/mapping 50X50/2_3min_b3_50X50_spectral_mapping_3.tif")
# Out:
# ImageJ series: detected extra dimension 'I'
# ImageJ series: detected extra dimension 'I'
# ImageJ series: detected extra dimension 'I'

# %% [markdown]
# #### 4 - Acetamiprid

# %%
aceta_batch1_3min_mapping = rd.read_data("data/20220421 SERS data generation/analyte 4/mapping50X50/4_3min_b3_50X50_spectral_mapping_1.tif")
aceta_batch2_3min_mapping = rd.read_data("data/20220421 SERS data generation/analyte 4/mapping50X50/4_3min_b3_50X50_spectral_mapping_2.tif")
aceta_batch3_3min_mapping = rd.read_data("data/20220421 SERS data generation/analyte 4/mapping50X50/4_3min_b3_50X50_spectral_mapping_3.tif")
# Out:
# ImageJ series: detected extra dimension 'I'
# ImageJ series: detected extra dimension 'I'
# ImageJ series: detected extra dimension 'I'

# %% [markdown]
# ## Visualize the data

# %% [markdown]
# #### Carbendazim: Raman and SERS

# %%
y_pos = 30000  # y position of the text
rotation_angle = 65  # angle of the text rotation

# %%
# Indene peaks
indene_peaks = [203, 381, 534, 592, 730, 861, 1019, 1068,
                1153, 1205, 1226, 1288, 1312, 1361, 1457, 1588, 1609]

indene_true_peaks = [180, 340, 480, 540, 680, 815, 989, 1048]

text_pos= [730, 1018, 1205, 1361, 1393, 1458, 1553, 1610]
text = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
# Carbendazim peaks
carbendazim_peaks = [617, 723, 960, 1018, 1260, 1270, 1473]

# %%
# Used only 650 and 1250 because Indene peaks went only till 1600
plt.figure(figsize=(30,20))
plt.plot(f_sup_785_650, car_650, color='blue')
plt.plot(f_sup_785_1250, car_1250, color='blue')
# plt.plot(f_sup_785_650, indene_650 + 10000, color='green')
# plt.plot(f_sup_785_1250 + 40, indene_1250 + 10000, color='green')
# plt.vlines(x=indene_peaks, ymin=16000, ymax=y_pos, colors="k", linestyles="dashed")
# plt.vlines(x=indene_true_peaks, ymin=16000, ymax=22500, color='r', linestyles='dashed')
# for peak_pos, peak_label in enumerate(indene_peaks):
#     plt.text(indene_peaks[peak_pos], y_pos, str(peak_label), rotation=rotation_angle)

# for true_peak in indene_true_peaks:
#     plt.text(x=true_peak, y=22500, s=str(true_peak), rotation=rotation_angle, color="red")
    
# for idx, true_peak in enumerate(text_pos):
#     plt.text(x=true_peak, y=30000, s=text[idx], rotation=rotation_angle, color='black')
    
# plt.vlines(x=[1100], y=)
plt.rc('font', size=20)
plt.title("Indene Raman")
plt.xlabel('Raman Shift cm^-1')
plt.ylabel('Intensity counts')
# Out:
# Text(0, 0.5, 'Intensity counts')

# %%
f_sup_785_1250
# Out:
# array([ 711.8393,  712.4261,  713.0128, ..., 1697.0833, 1697.4882,
#        1697.8931])

# %%
# Used only 650 and 1250 because Indene peaks went only till 1600
plt.figure(figsize=(30,20))
plt.plot(f_sup_785_650[:1110], car_650[:1110] / np.max(car_650) + 1.17, color='blue')
plt.plot(f_sup_785_1250, car_1250 / np.max(car_1250) + 1, color='blue')
plt.plot(f_sup_sers, np.mean(car_batch1_3min_mapping, axis=0) / np.max(np.mean(car_batch1_3min_mapping, axis=0)), color='g')
plt.vlines(x=carbendazim_peaks, ymin=0, ymax=2, colors="k", linestyles="dashed")    
for idx, true_peak in enumerate(carbendazim_peaks):
    plt.text(x=true_peak, y=2, s=str(true_peak), rotation=rotation_angle, color='black')
    
plt.rc('font', size=20)
plt.title("Carbendazim Raman")
plt.xlabel('Raman Shift cm^-1')
plt.ylabel('Intensity counts')
# Out:
# Text(0, 0.5, 'Intensity counts')

# %% [markdown]
# #### Thiacloprid: Raman and SERS

# %%
# Thiacloprid peaks
thia_peaks = [588, 639, 688, 815, 1009, 1096, 1424, 1585]

# %%
plt.figure(figsize=(30,20))
plt.plot(f_sup_sers, car_650, color='blue')
plt.vlines(x=carbendazim_peaks, ymin=0, ymax=25000, colors="k", linestyles="dashed")    
for idx, true_peak in enumerate(carbendazim_peaks):
    plt.text(x=true_peak, y=25000, s=str(true_peak), rotation=rotation_angle, color='black')
    
plt.rc('font', size=20)
plt.title("Carbendazim Raman")
plt.xlabel('Raman Shift cm^-1')
plt.ylabel('Intensity counts')
