# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, '../')

# %%
from tools.ramanflow.read_data import ReadData as rd
from tools.ramanflow.prep_data import PrepData as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### UV Spectra

# %%
wavelength, batch1_1_30sec_1min = rd.read_uv_data('../data/UV/20220303/batch1+1_30sec_1.txt')

# %%
wavelength, batch1_1_30sec_30min = rd.read_uv_data('../data/UV/20220303/batch1+1_30sec_2.txt')

# %%
wavelength, batch1_1_30sec_1h = rd.read_uv_data('../data/UV/20220303/batch1+1_30sec_3.txt')

# %%
wavelength, batch1_1_30sec_3h = rd.read_uv_data('../data/UV/20220303/batch1+1_30sec_4.txt')

# %%
wavelength, batch1_1_3min_1min = rd.read_uv_data('../data/UV/20220303/batch1+1_3min_1.txt')

# %%
wavelength, batch1_1_3min_30min = rd.read_uv_data('../data/UV/20220303/batch1+1_3min_2.txt')

# %%
wavelength, batch1_1_3min_1h = rd.read_uv_data('../data/UV/20220303/batch1+1_3min_3.txt')

# %%
wavelength, batch1_1_3min_3h = rd.read_uv_data('../data/UV/20220303/batch1+1_3min_4.txt')

# %%
wavelength, batch2_1_30sec_1min = rd.read_uv_data('../data/UV/20220303/batch2+1_30sec_1.txt')

# %%
wavelength, batch2_1_30sec_30min = rd.read_uv_data('../data/UV/20220303/batch2+1_30sec_2.txt')

# %%
wavelength, batch2_1_30sec_1h = rd.read_uv_data('../data/UV/20220303/batch2+1_30sec_3.txt')

# %%
wavelength, batch2_1_30sec_3h = rd.read_uv_data('../data/UV/20220303/batch2+1_30sec_4.txt')

# %%
wavelength, batch2_1_3min_1min = rd.read_uv_data('../data/UV/20220303/batch2+1_3min_1.txt')

# %%
wavelength, batch2_1_3min_30min = rd.read_uv_data('../data/UV/20220303/batch2+1_3min_2.txt')

# %%
wavelength, batch2_1_3min_1h = rd.read_uv_data('../data/UV/20220303/batch2+1_3min_3.txt')

# %%
wavelength, batch2_1_3min_3h = rd.read_uv_data('../data/UV/20220303/batch2+1_3min_4.txt')

# %%
wavelength, batch3_1_30sec_1min = rd.read_uv_data('../data/UV/20220303/batch3+1_30sec_1.txt')

# %%
wavelength, batch3_1_30sec_30min = rd.read_uv_data('../data/UV/20220303/batch3+1_30sec_2.txt')

# %%
wavelength, batch3_1_30sec_1h = rd.read_uv_data('../data/UV/20220303/batch3+1_30sec_3.txt')

# %%
wavelength, batch3_1_30sec_3h = rd.read_uv_data('../data/UV/20220303/batch3+1_30sec_4.txt')

# %%
wavelength, batch3_1_3min_1min = rd.read_uv_data('../data/UV/20220303/batch3+1_3min_1.txt')

# %%
wavelength, batch3_1_3min_30min = rd.read_uv_data('../data/UV/20220303/batch3+1_3min_2.txt')

# %%
wavelength, batch3_1_3min_1h = rd.read_uv_data('../data/UV/20220303/batch3+1_3min_3.txt')

# %%
wavelength, batch3_1_3min_3h = rd.read_uv_data('../data/UV/20220303/batch3+1_3min_4.txt')

# %%
wavelength, batch1_4_3min_12h = rd.read_uv_data('../data/UV/20220303/batch1+4_3min_1.txt')

# %%
wavelength, batch1_4_30sec_12h = rd.read_uv_data('../data/UV/20220303/batch1+4_30sec_1.txt')

# %%
wavelength, batch2_4_30sec_12h = rd.read_uv_data('../data/UV/20220303/batch2+4_30sec_1.txt')

# %%
wavelength, batch2_4_3min_12h = rd.read_uv_data('../data/UV/20220303/batch2+4_3min_1.txt')

# %%
wavelength, batch3_4_30sec_12h = rd.read_uv_data('../data/UV/20220303/batch3+4_30sec_1.txt')

# %%
wavelength, batch3_4_3min_12h = rd.read_uv_data('../data/UV/20220303/batch3+4_3min_1.txt')

# %%
wavelength, batch1_30sec_12h = rd.read_uv_data('../data/UV/20220303/batch1_30sec_1.txt')

# %%
wavelength, batch1_3min_12h = rd.read_uv_data('../data/UV/20220303/batch1_3min_1.txt')

# %%
wavelength, batch2_30sec_12h = rd.read_uv_data('../data/UV/20220303/batch2_30sec_1.txt')

# %%
wavelength, batch2_3min_12h = rd.read_uv_data('../data/UV/20220303/batch2_3min_1.txt')

# %%
wavelength, batch3_30sec_12h = rd.read_uv_data('../data/UV/20220303/batch3_30sec_1.txt')

# %%
wavelength, batch3_3min_12h = rd.read_uv_data('../data/UV/20220303/batch3_3min_1.txt')

# %%
wavelength, batch1_30sec_1min = rd.read_uv_data('../data/UV/20220302/batch1_30sec.txt')

# %%
wavelength, batch1_3min_1min = rd.read_uv_data('../data/UV/20220302/batch1_3min_.txt')

# %%
wavelength, batch2_30sec_1min = rd.read_uv_data('../data/UV/20220302/batch2_30sec_.txt')

# %%
wavelength, batch2_3min_1min = rd.read_uv_data('../data/UV/20220302/batch2_3min_.txt')

# %%
wavelength, batch3_30sec_1min = rd.read_uv_data('../data/UV/20220302/batch3_30sec_.txt')

# %%
wavelength, batch3_3min_1min = rd.read_uv_data('../data/UV/20220302/batch3_3min_.txt')

# %%
batches = [batch1_30sec_1min, batch2_30sec_1min, batch3_30sec_1min]

plt.figure(figsize=(10,7))

for i, batch in enumerate(batches, start=1):
    plt.plot(wavelength, batch, label=f"batch {i}")

plt.ylabel("wavelength", fontsize=20)
plt.xlabel("Absorption", fontsize=20)
plt.title("3 batches 30sec", fontsize=17)
plt.grid()
plt.legend()
plt.show()

# %%
batches = [batch1_3min_1min, batch2_3min_1min, batch3_3min_1min]

plt.figure(figsize=(10,7))

for i, batch in enumerate(batches, start=1):
    plt.plot(wavelength, batch, label=f"batch {i}")

plt.ylabel("wavelength", fontsize=20)
plt.xlabel("Absorption", fontsize=20)
plt.title("3 batches 3min", fontsize=17)
plt.grid()
plt.legend()
plt.show()

# %%
batches_immediate = [batch1_3min_1min, batch2_3min_1min, batch3_3min_1min]
batches_12h = [batch1_3min_12h, batch2_3min_12h, batch3_3min_12h]

plt.figure(figsize=(10,7))

for i, batch in enumerate(batches_immediate, start=1):
    plt.plot(wavelength, batch, label=f"batch {i} immediate")

for i, batch in enumerate(batches_12h, start=1):
    plt.plot(wavelength, batch, label=f"batch {i} 12h")

plt.ylabel("wavelength", fontsize=20)
plt.xlabel("Absorption", fontsize=20)
plt.title("3 batches 3min", fontsize=17)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Batch 1 Spectras

# %%
f_sup, batch1_1_30sec_1min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_30sec+1_1min_6X6_mapping.tif')

f_sup, batch1_1_30sec_30min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_30sec+1_30min_6X6_mapping.tif')

f_sup, batch1_1_30sec_1h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_30sec+1_1h_6X6_mapping.tif')

f_sup, batch1_1_30sec_3h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_30sec+1_3h_6X6_mapping.tif')

f_sup, batch1_1_3min_1min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_3min+1_1min_6X6_mapping.tif')

f_sup, batch1_1_3min_30min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_3min+1_30min_6X6_mapping.tif')

f_sup, batch1_1_3min_1h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_3min+1_1h_6X6_mapping.tif')

f_sup, batch1_1_3min_3h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_3min+1_3h_6X6_mapping.tif')

f_sup, batch1_4_30sec_12h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_30sec+4_6X6_mapping.tif')

f_sup, batch1_4_30sec_22h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_30sec+4_22h_6X6_mapping.tif')

f_sup, batch1_4_3min_22h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_3min+4_22h_6X6_mapping.tif')

f_sup, batch1_4_3min_12h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_3min+4_6X6_mapping.tif')

f_sup, batch1_3min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_3min_6X6_mapping.tif')

f_sup, batch1_30sec_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch1/batch1_30sec_6X6_mapping.tif')

# %% [markdown]
# ### Batch 2 Spectras

# %%
f_sup, batch2_1_30sec_1min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_30sec+1_1min_6X6_mapping.tif')

f_sup, batch2_1_30sec_30min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_30sec+1_30min_6X6_mapping.tif')

f_sup, batch2_1_30sec_1h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_30sec+1_1h_6X6_mapping.tif')

f_sup, batch2_1_30sec_3h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_30sec+1_3h_6X6_mapping.tif')

f_sup, batch2_1_3min_1min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_3min+1_1min_6X6_mapping.tif')

f_sup, batch2_1_3min_30min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_3min+1_30min_6X6_mapping.tif')

f_sup, batch2_1_3min_1h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_3min+1_1h_6X6_mapping.tif')

f_sup, batch2_1_3min_3h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_3min+1_3h_6X6_mapping.tif')

f_sup, batch2_4_30sec_12h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_30sec+4_6X6_mapping.tif')

f_sup, batch2_4_30sec_22h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_30sec+4_22h_6X6_mapping.tif')

f_sup, batch2_4_3min_22h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_3min+4_22h_6X6_mapping.tif')

f_sup, batch2_4_3min_12h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_3min+4_6X6_mapping.tif')

f_sup, batch2_3min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_3min_6X6_mapping.tif')

f_sup, batch2_30sec_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch2/batch2_30sec_6X6_mapping.tif')

# %% [markdown]
# ### Batch 3 Spectras

# %%
f_sup, batch3_1_30sec_1min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_30sec+1_1min_6X6_mapping.tif')

f_sup, batch3_1_30sec_30min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_30sec+1_30min_6X6_mapping.tif')

f_sup, batch3_1_30sec_1h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_30sec+1_1h_6X6_mapping.tif')

f_sup, batch3_1_30sec_3h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_30sec+1_3h_6X6_mapping.tif')

f_sup, batch3_1_3min_1min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_3min+1_1min_6X6_mapping.tif')

f_sup, batch3_1_3min_30min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_3min+1_30min_6X6_mapping.tif')

f_sup, batch3_1_3min_1h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_3min+1_1h_6X6_mapping.tif')

f_sup, batch3_1_3min_3h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_3min+1_4h_6X6_mapping.tif')

f_sup, batch3_4_30sec_12h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_30sec+4_6X6_mapping.tif')

f_sup, batch3_4_30sec_22h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_30sec+4_22h_6X6_mapping.tif')

f_sup, batch3_4_3min_22h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_3min+4_22h_6X6_mapping.tif')

f_sup, batch3_4_3min_12h_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_3min+4_6X6_mapping.tif')

f_sup, batch3_3min_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_3min_6X6_mapping.tif')

f_sup, batch3_30sec_mapping = rd.read_data('../data/20220303 SERS repeatibility test/batch3/batch3_30sec_6X6_mapping.tif')

# %% [markdown]
# ### MG Test

# %%
f_sup, batch1_mg_30sec = rd.read_data("../data/20220303 SERS repeatibility test/MG/batch1_30sec+MG150ppb.tif")

f_sup, batch1_mg_3min = rd.read_data("../data/20220303 SERS repeatibility test/MG/batch1_3min+MG150ppb.tif")

f_sup, batch2_mg_30sec = rd.read_data("../data/20220303 SERS repeatibility test/MG/batch2_30sec+MG150ppb.tif")

f_sup, batch2_mg_3min = rd.read_data("../data/20220303 SERS repeatibility test/MG/batch2_3min+MG150ppb.tif")

f_sup, batch3_mg_30sec = rd.read_data("../data/20220303 SERS repeatibility test/MG/batch3_30sec+MG150ppb.tif")

f_sup, batch3_mg_3min = rd.read_data("../data/20220303 SERS repeatibility test/MG/batch3_3min+MG150ppb.tif")

# %%
plt.figure(figsize=(25,15))
plt.plot(wavelength, batch1_30sec_1min, "b", label="batch 1 immediate")
plt.plot(wavelength, batch2_30sec_1min, "y", label="batch 2 immediate")
plt.plot(wavelength, batch3_30sec_1min, "g", label="batch 3 immediate")
plt.plot(wavelength, batch1_30sec_12h, "^b", label="batch 1 12h")
plt.plot(wavelength, batch2_30sec_12h, "^y", label="batch 2 12h")
plt.plot(wavelength, batch3_30sec_12h, "^g", label="batch 3 12h")
plt.vlines(wavelength[53], ymin=np.min(batch3_30sec_12h), ymax=np.max(batch3_30sec_12h), colors='k', linestyles='dashed')
plt.annotate(str(wavelength[53]), (wavelength[53], batch3_30sec_12h[53]), fontsize=23)
plt.ylabel("Absorption", fontsize=20)
plt.xlabel("wavelength", fontsize=20)
plt.title("3 batches 30sec", fontsize=25)
plt.xticks(np.arange(wavelength[0], wavelength[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
plt.savefig("3batches_30sec_1min_12h_abs.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
plt.plot(wavelength, batch1_1_30sec_1min, "b", label="batch 1 30sec")
plt.plot(wavelength, batch1_1_3min_1min, "y", label="batch 1 3min")
# plt.vlines(wavelength[53], ymin=np.min(batch3_30sec_12h), ymax=np.max(batch3_30sec_12h), colors='k', linestyles='dashed')
# plt.annotate(str(wavelength[53]), (wavelength[53], batch3_30sec_12h[53]), fontsize=23)
plt.ylabel("Absorption", fontsize=20)
plt.xlabel("wavelength", fontsize=20)
plt.title("Batch 1 + 1", fontsize=25)
plt.xticks(np.arange(wavelength[0], wavelength[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
# plt.savefig("3batches_30sec_1min_12h_abs.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
plt.plot(wavelength, batch2_1_30sec_1min, "b", label="batch 2 30sec")
plt.plot(wavelength, batch2_1_3min_1min, "y", label="batch 2 3min")
# plt.vlines(wavelength[53], ymin=np.min(batch3_30sec_12h), ymax=np.max(batch3_30sec_12h), colors='k', linestyles='dashed')
# plt.annotate(str(wavelength[53]), (wavelength[53], batch3_30sec_12h[53]), fontsize=23)
plt.ylabel("Absorption", fontsize=20)
plt.xlabel("wavelength", fontsize=20)
plt.title("Batch 2 + 1", fontsize=25)
plt.xticks(np.arange(wavelength[0], wavelength[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
# plt.savefig("3batches_30sec_1min_12h_abs.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
plt.plot(wavelength, batch3_1_30sec_1min, "b", label="batch 3 30sec")
plt.plot(wavelength, batch3_1_3min_1min, "y", label="batch 3 3min")
# plt.vlines(wavelength[53], ymin=np.min(batch3_30sec_12h), ymax=np.max(batch3_30sec_12h), colors='k', linestyles='dashed')
# plt.annotate(str(wavelength[53]), (wavelength[53], batch3_30sec_12h[53]), fontsize=23)
plt.ylabel("Absorption", fontsize=20)
plt.xlabel("wavelength", fontsize=20)
plt.title("Batch 3 + 1", fontsize=25)
plt.xticks(np.arange(wavelength[0], wavelength[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
# plt.savefig("3batches_30sec_1min_12h_abs.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
plt.plot(wavelength, batch1_4_30sec_12h, "b", label="batch 1 30sec")
plt.plot(wavelength, batch1_4_3min_12h, "y", label="batch 1 3min")
# plt.vlines(wavelength[53], ymin=np.min(batch3_30sec_12h), ymax=np.max(batch3_30sec_12h), colors='k', linestyles='dashed')
# plt.annotate(str(wavelength[53]), (wavelength[53], batch3_30sec_12h[53]), fontsize=23)
plt.ylabel("Absorption", fontsize=20)
plt.xlabel("wavelength", fontsize=20)
plt.title("Batch 1 + 4", fontsize=25)
plt.xticks(np.arange(wavelength[0], wavelength[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
# plt.savefig("3batches_30sec_1min_12h_abs.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
plt.plot(wavelength, batch2_4_30sec_12h, "b", label="batch 1 30sec")
plt.plot(wavelength, batch2_4_3min_12h, "y", label="batch 1 3min")
# plt.vlines(wavelength[53], ymin=np.min(batch3_30sec_12h), ymax=np.max(batch3_30sec_12h), colors='k', linestyles='dashed')
# plt.annotate(str(wavelength[53]), (wavelength[53], batch3_30sec_12h[53]), fontsize=23)
plt.ylabel("Absorption", fontsize=20)
plt.xlabel("wavelength", fontsize=20)
plt.title("Batch 2 + 4", fontsize=25)
plt.xticks(np.arange(wavelength[0], wavelength[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
# plt.savefig("3batches_30sec_1min_12h_abs.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
plt.plot(wavelength, batch3_4_30sec_12h, "b", label="batch 3 30sec")
plt.plot(wavelength, batch3_4_3min_12h, "y", label="batch 3 3min")
# plt.vlines(wavelength[53], ymin=np.min(batch3_30sec_12h), ymax=np.max(batch3_30sec_12h), colors='k', linestyles='dashed')
# plt.annotate(str(wavelength[53]), (wavelength[53], batch3_30sec_12h[53]), fontsize=23)
plt.ylabel("Absorption", fontsize=20)
plt.xlabel("wavelength", fontsize=20)
plt.title("Batch 3 + 4", fontsize=25)
plt.xticks(np.arange(wavelength[0], wavelength[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
# plt.savefig("3batches_30sec_1min_12h_abs.jpg", dpi=700)

# %%
np.where(batch3_30sec_12h == np.max(batch3_30sec_12h))
# wavelength[53]

# %%
plt.figure(figsize=(25,15))
plt.plot(wavelength, batch1_30sec_1min, "b", label="batch 1 immediate")
plt.plot(wavelength, batch2_30sec_1min, "y", label="batch 2 immediate")

plt.vlines(wavelength[53], ymin=np.min(batch3_30sec_12h), ymax=np.max(batch3_30sec_12h), colors='k', linestyles='dashed')
plt.annotate(str(wavelength[53]), (wavelength[53], batch3_30sec_12h[53]), fontsize=23)
plt.ylabel("Absorption", fontsize=20)
plt.xlabel("wavelength", fontsize=20)
plt.title("3 batches 30sec", fontsize=25)
plt.xticks(np.arange(wavelength[0], wavelength[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
plt.savefig("3batches_30sec_1min_12h_abs.jpg", dpi=700)

# %%
fig, axs = plt.subplots(3, figsize=(25,15))
fig.suptitle('Batch 2 30sec + 1', fontsize=25)
axs[0].plot(wavelength, batch2_30sec_12h, label="batch 12h later UV")
axs[1].plot(wavelength, batch2_1_30sec_1min, label="1 + batch 1 30sec UV")
axs[2].plot(f_sup, np.mean(batch2_1_30sec_1min_mapping, axis=0), label="1 + batch2 30sec")
axs[2].set_ylabel("Intensity", fontsize=20)
axs[2].set_xlabel("Raman Shift", fontsize=20)
axs[2].set_xticks(np.arange(f_sup[0], f_sup[-1], 150), fontsize=16)
# axs[2].set_yticks(fontsize=14)
# plt.legend(fontsize=25)
# plt.savefig("batch2_30sec_1_uv_raman.jpg", dpi=700)

# %%
fig, axs = plt.subplots(3, figsize=(25,15))
fig.suptitle('Batch 2 3min + 4', fontsize=25)
axs[0].plot(wavelength, batch2_3min_12h)#, label="batch 12h later UV")
axs[1].plot(wavelength, batch2_4_3min_12h)#, label="1 + batch 1 30sec UV")
axs[2].plot(f_sup, np.mean(batch2_4_3min_12h_mapping, axis=0), label="4 + batch2 3min")
axs[2].set_ylabel("Intensity", fontsize=20)
axs[2].set_xlabel("Raman Shift", fontsize=20)
axs[2].set_xticks(np.arange(f_sup[0], f_sup[-1], 150), fontsize=16)
# axs[2].set_yticks(fontsize=14)
# plt.legend(fontsize=25)
plt.savefig("batch2_3min_4_uv_raman.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
plt.plot(f_sup, np.mean(batch1_1_30sec_1min_mapping, axis = 0), "b", label="batch 1 immediate")
plt.plot(f_sup, np.mean(batch2_1_30sec_1min_mapping, axis = 0), "y", label="batch 2 immediate")
plt.plot(f_sup, np.mean(batch3_1_30sec_1min_mapping, axis = 0), "g", label="batch 3 immediate")
plt.ylabel("Intensity", fontsize=20)
plt.xlabel("Raman Shift cm^-1", fontsize=20)
plt.title("3 batches 30sec + 1", fontsize=25)
plt.xticks(np.arange(f_sup[0], f_sup[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
plt.savefig("3batches1_30sec_1min_12h_raman.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
plt.plot(f_sup[170:], np.mean(batch1_1_3min_1min_mapping, axis = 0)[170:], "b", label="batch 1 immediate")
# plt.plot(f_sup, np.mean(batch2_1_3min_1min_mapping, axis = 0), "y", label="batch 2 immediate")
# plt.plot(f_sup, np.mean(batch3_1_3min_1min_mapping, axis = 0), "g", label="batch 3 immediate")
plt.ylabel("Intensity", fontsize=20)
plt.xlabel("Raman Shift cm^-1", fontsize=20)
plt.title("3 batches 3min + 1", fontsize=25)
plt.xticks(np.arange(f_sup[0], f_sup[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
# plt.savefig("3batches1_3min_1min_12h_raman.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
plt.plot(f_sup, np.mean(batch1_4_30sec_12h_mapping, axis = 0), "b", label="batch 1 ")
plt.plot(f_sup, np.mean(batch2_4_30sec_12h_mapping, axis = 0), "y", label="batch 2 ")
plt.plot(f_sup, np.mean(batch3_4_30sec_12h_mapping, axis = 0), "g", label="batch 3 ")
plt.ylabel("Intensity", fontsize=20)
plt.xlabel("Raman Shift cm^-1", fontsize=20)
plt.title("3 batches 3min + 4", fontsize=25)
plt.xticks(np.arange(f_sup[0], f_sup[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
# plt.savefig("3batches1_30sec_12h_raman_4.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
plt.plot(f_sup, np.mean(batch1_mg_3min, axis = 0), "b", label="batch 1 ")
plt.plot(f_sup, np.mean(batch2_mg_3min, axis = 0), "y", label="batch 2 ")
plt.plot(f_sup, np.mean(batch3_mg_3min, axis = 0), "g", label="batch 3 ")
plt.ylabel("Intensity", fontsize=20)
plt.xlabel("Raman Shift cm^-1", fontsize=20)
plt.title("3 batches 3min + MG", fontsize=25)
plt.xticks(np.arange(f_sup[0], f_sup[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
plt.savefig("3batches1_3min_12h_raman_MG.jpg", dpi=700)

# %%
plt.figure(figsize=(25,15))
for i in range(0, len(batch3_mg_3min)):
    plt.plot(f_sup, batch3_mg_3min[i], linestyle='dashed')
plt.plot(f_sup, np.mean(batch3_mg_3min, axis = 0), "r", label="batch 3 immediate", linestyle='solid', linewidth=3.0)
# plt.plot(f_sup, np.mean(batch2_1_30sec_1min_mapping, axis = 0), "y", label="batch 2 immediate")
# plt.plot(f_sup, np.mean(batch3_1_30sec_1min_mapping, axis = 0), "g", label="batch 3 immediate")
plt.ylabel("Intensity", fontsize=20)
plt.xlabel("Raman Shift cm^-1", fontsize=20)
plt.title("Batch 3 3min + MG", fontsize=25)
plt.xticks(np.arange(f_sup[0], f_sup[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
plt.savefig("batch3_3min+MG_mean_&_all.jpg", dpi=700)

# %% [markdown]
# ### 25/03/2022 Reproducibility test
#
# #### Here we were testing analytes #2, #3, #4, #5
#
# Analytes:
# 2. Thiacloprid
# 3. Imidacloprid
# 4. Acetamiprid
# 5. Acephate

# %% [markdown]
# ### 2

# %%
f_sup, batch1_2_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 2/2_30s_b1.tif')

f_sup, batch1_2_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 2/2_3min_b1.tif')

f_sup, batch2_2_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 2/2_30s_b2.tif')

f_sup, batch2_2_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 2/2_3min_b2.tif')

f_sup, batch3_2_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 2/2_30s_b3.tif')

f_sup, batch3_2_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 2/2_3min_b3.tif')
# Out:
# <tifffile.TiffFile '2_30s_b1.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '2_3min_b1.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '2_30s_b2.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '2_3min_b2.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '2_30s_b3.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '2_3min_b3.tif'> ImageJ series contains unidentified dimension

# %%
plt.figure(figsize=(25,15))
# plt.plot(f_sup, np.mean(batch1_2_3min_mapping, axis = 0), "b", label="2 + batch 1 12h")
# plt.plot(f_sup, np.mean(batch2_2_3min_mapping, axis = 0), "y", label="2 + batch 2 12h")
# plt.plot(f_sup, np.mean(batch3_2_3min_mapping, axis = 0), "g", label="2 + batch 3 12h")
# plt.plot(f_sup, np.mean(batch1_4_3min_mapping, axis = 0), "b", label="4 + batch 1 12h")
plt.plot(f_sup[62:], np.mean(batch2_4_3min_mapping, axis = 0)[62:], "k", label="4 + batch 2 12h")
# plt.plot(f_sup, np.mean(batch2_2_3min_mapping, axis = 0), "k", label="2 + batch 2")
# plt.plot(f_sup, np.mean(batch3_4_3min_mapping, axis = 0), "g", label="4 + batch 3 12h")
plt.fill_between(f_sup[62:], np.mean(batch2_4_3min_mapping, axis = 0)[62:], facecolor='black', alpha=0.1)
plt.ylabel("Intensity", fontsize=20)
plt.xlabel("Raman Shift cm^-1", fontsize=20)
plt.title("3 batches 3min + 2", fontsize=25)
plt.xticks(np.arange(f_sup[0], f_sup[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
# plt.legend(fontsize=25)
plt.show()
# plt.savefig("3batches1_3min_1min_12h_raman.jpg", dpi=700)

# %% [markdown]
# ### 3

# %%
f_sup, batch1_3_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 3/3_30s_b1.tif')

f_sup, batch1_3_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 3/3_3min_b1.tif')

f_sup, batch2_3_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 3/3_30s_b2.tif')

f_sup, batch2_3_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 3/3_3min_b2.tif')

f_sup, batch3_3_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 3/3_30s_b3.tif')

f_sup, batch3_3_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 3/3_3min_b3.tif')
# Out:
# <tifffile.TiffFile '3_30s_b1.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '3_3min_b1.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '3_30s_b2.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '3_3min_b2.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '3_30s_b3.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '3_3min_b3.tif'> ImageJ series contains unidentified dimension

# %%
plt.figure(figsize=(25,15))
plt.plot(f_sup, np.mean(batch1_3_30sec_mapping, axis = 0), "b", label="batch 1 12h")
plt.plot(f_sup, np.mean(batch2_3_30sec_mapping, axis = 0), "y", label="batch 2 12h")
plt.plot(f_sup, np.mean(batch3_3_30sec_mapping, axis = 0), "g", label="batch 3 12h")
plt.ylabel("Intensity", fontsize=20)
plt.xlabel("Raman Shift cm^-1", fontsize=20)
plt.title("3 batches 30sec + 3", fontsize=25)
plt.xticks(np.arange(f_sup[0], f_sup[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
plt.show()
# plt.savefig("3batches1_3min_1min_12h_raman.jpg", dpi=700)

# %% [markdown]
# ### 4

# %%
f_sup, batch1_4_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 4/4_30s_b1.tif')

f_sup, batch1_4_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 4/4_3min_b1.tif')

f_sup, batch2_4_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 4/4_30s_b2.tif')

f_sup, batch2_4_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 4/4_3min_b2.tif')

f_sup, batch3_4_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 4/4_30s_b3.tif')

f_sup, batch3_4_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 4/4_3min_b3.tif')
# Out:
# <tifffile.TiffFile '4_30s_b1.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '4_3min_b1.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '4_30s_b2.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '4_3min_b2.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '4_30s_b3.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '4_3min_b3.tif'> ImageJ series contains unidentified dimension

# %%
plt.figure(figsize=(25,15))
# plt.plot(f_sup, np.mean(batch1_4_30sec_mapping, axis = 0), "b", label="batch 1 12h")
# plt.plot(f_sup, np.mean(batch2_4_30sec_mapping, axis = 0), "y", label="batch 2 12h")
plt.plot(f_sup, np.mean(batch3_4_30sec_mapping, axis = 0), "g", label="batch 3 12h")
plt.ylabel("Intensity", fontsize=20)
plt.xlabel("Raman Shift cm^-1", fontsize=20)
plt.title("3 batches 3min + 4", fontsize=25)
plt.xticks(np.arange(f_sup[0], f_sup[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
plt.show()
# plt.savefig("3batches1_3min_1min_12h_raman.jpg", dpi=700)

# %% [markdown]
# ### 5

# %%
f_sup, batch1_5_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 5/5_30s_b1.tif')

f_sup, batch1_5_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 5/5_3min_b1.tif')

f_sup, batch2_5_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 5/5_30s_b2.tif')

f_sup, batch2_5_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 5/5_3min_b2.tif')

f_sup, batch3_5_30sec_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 5/5_30s_b3.tif')

f_sup, batch3_5_3min_mapping = rd.read_data('data/20220325 SERS repeatibility test/analyte 5/5_3min_b3.tif')
# Out:
# <tifffile.TiffFile '5_30s_b1.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '5_3min_b1.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '5_30s_b2.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '5_3min_b2.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '5_30s_b3.tif'> ImageJ series contains unidentified dimension
# <tifffile.TiffFile '5_3min_b3.tif'> ImageJ series contains unidentified dimension

# %%
plt.figure(figsize=(25,15))
plt.plot(f_sup, np.mean(batch1_5_30sec_mapping, axis = 0), "b", label="batch 1 12h")
plt.plot(f_sup, np.mean(batch2_5_30sec_mapping, axis = 0), "y", label="batch 2 12h")
plt.plot(f_sup, np.mean(batch3_5_30sec_mapping, axis = 0), "g", label="batch 3 12h")
plt.ylabel("Intensity", fontsize=20)
plt.xlabel("Raman Shift cm^-1", fontsize=20)
plt.title("3 batches 30s + 5", fontsize=25)
plt.xticks(np.arange(f_sup[0], f_sup[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
plt.show()
# plt.savefig("3batches1_3min_1min_12h_raman.jpg", dpi=700)

# %% [markdown]
# ## Diffrence between 3 batches

# %%
# Take 3rd batch of UV spectra as a reference
# Subtract the reference from the other batches
# Plot the difference and see if there is any trend

plt.figure(figsize=(25,15))
plt.plot(wavelength, batch1_30sec_1min - batch3_30sec_1min, "b", label="batch 1 immediate")
plt.plot(wavelength, batch2_30sec_1min - batch3_30sec_1min, "y", label="batch 2 immediate")
plt.xlabel("wavelength", fontsize=20)
plt.ylabel("Absorption", fontsize=20)
plt.title("3 batches 30sec", fontsize=25)
plt.xticks(np.arange(wavelength[0], wavelength[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
plt.grid()
plt.show()

# %%
# show me UV variables

plt.figure(figsize=(25,15))
plt.plot(wavelength, batch1_30sec_1min, "b", label="batch 1 immediate")
plt.plot(wavelength, batch2_30sec_1min, "y", label="batch 2 immediate")
plt.plot(wavelength, batch3_30sec_1min, "g", label="batch 3 immediate")
plt.xlabel("wavelength", fontsize=20)
plt.ylabel("Absorption", fontsize=20)
plt.title("3 batches 30sec", fontsize=25)
plt.xticks(np.arange(wavelength[0], wavelength[-1], 100), fontsize=16)
plt.yticks(fontsize=14)
plt.legend(fontsize=25)
plt.grid()
plt.show()

# %%
# Read UV data from 20220804 from UV folder

wavelength, batch1_3min = rd.read_data("../data/UV/20220804/batch1_3min_.txt")

# %%
plt.plot(wavelength, batch1_3min)

# %%
whos
# Out:
# Variable                       Type       Data/Info
# ---------------------------------------------------
# batch1_1_30sec_1h              ndarray    251: 251 elems, type `float64`, 2008 bytes
# batch1_1_30sec_1h_mapping      ndarray    36x1600: 57600 elems, type `float64`, 460800 bytes (450.0 kb)
# batch1_1_30sec_1min            ndarray    251: 251 elems, type `float64`, 2008 bytes
# batch1_1_30sec_1min_mapping    ndarray    36x1600: 57600 elems, type `float64`, 460800 bytes (450.0 kb)
# batch1_1_30sec_30min           ndarray    251: 251 elems, type `float64`, 2008 bytes
# batch1_1_30sec_30min_mapping   ndarray    36x1600: 57600 elems, type `float64`, 460800 bytes (450.0 kb)
# batch1_1_30sec_3h              ndarray    251: 251 elems, type `float64`, 2008 bytes
# batch1_1_30sec_3h_mapping      ndarray    36x1600: 57600 elems, type `float64`, 460800 bytes (450.0 kb)
# batch1_1_3min_1h               ndarray    251: 251 elems, type `float64`, 2008 bytes
# ...

# %%
wavelength, batch1_3min = rd.read_data("../data/UV/20220303/batch1_3min_1.txt")

# %%
plt.plot(wavelength, batch1_3min)

# %%
np.max(batch1_3min)
# Out:
# 1.89313

# %%
wavelength, batch3_3min = rd.read_data("../data/UV/20220303/batch3_3min_1.txt")

# %%
plt.plot(wavelength, batch3_3min)
